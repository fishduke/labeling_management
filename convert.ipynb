# %%
import os
import json
import glob

# Path to the directory containing JSON files
path = '\\\\192.168.100.79\\fishduke\\home\\data2\\bear\\labels\\'

def convert_bbox_to_yolo(size, box):
    dw = 1. / size[0]
    dh = 1. / size[1]
    x = (box[0] + box[2]) / 2.0 - 1
    y = (box[1] + box[3]) / 2.0 - 1
    w = box[2] - box[0]
    h = box[3] - box[1]
    x = x * dw
    w = w * dw
    y = y * dh
    h = h * dh
    return (x, y, w, h)

def process_json_files(path):
    # Make sure the path exists
    if not os.path.exists(path):
        raise Exception(f"The specified path does not exist: {path}")

    # List all JSON files in the directory
    json_files = glob.glob(os.path.join(path, '*.json'))
    total_files = len(json_files)
    
    # Check if there are any files to process
    if total_files == 0:
        print("No JSON files found to process.")
        return

    # Process each JSON file
    for index, json_file_path in enumerate(json_files, start=1):
        with open(json_file_path, 'r') as file:
            data = json.load(file)

        # Extract image dimensions
        image_width = data['images'][0]['width']
        image_height = data['images'][0]['height']

        # Open the corresponding txt file for writing
        txt_file_path = json_file_path.replace('.json', '.txt')
        with open(txt_file_path, 'w') as txt_file:
            # Iterate over each annotation (object)
            for annotation in data['annotations']:
                bbox = annotation['bbox']
                try:
                    x_min, y_min, x_max, y_max = bbox[0][0], bbox[0][1], bbox[1][0], bbox[1][1]

                    # Convert bbox to YOLO format
                    yolo_bbox = convert_bbox_to_yolo((image_width, image_height), (x_min, y_min, x_max, y_max))

                    # Write the YOLO format to the txt file
                    txt_file.write(f"0 {yolo_bbox[0]} {yolo_bbox[1]} {yolo_bbox[2]} {yolo_bbox[3]}\n")
                except:
                    txt_file.write("")

        # Print progress on the same line
        percentage_complete = (index / total_files) * 100
        print(f"Processed {index} of {total_files} files ({percentage_complete:.2f}% complete)", end='\r')

    # Ensure the final message is on a new line after completion
    print()

# Run the processing function
process_json_files(path)
# Out:
# Processed 14960 of 14960 files (100.00% complete)

# %%
import os
import shutil

def is_valid_yolo_format(file_path):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            for line in lines:
                parts = line.strip().split()
                if len(parts) == 5 and all(part.replace('.', '', 1).isdigit() for part in parts[1:]):
                    return True
    except:
        pass
    return False

def count_total_images(base_path):
    total_images = 0
    for root, _, files in os.walk(base_path):
        if root == base_path:
            continue
        total_images += len([f for f in files if f.lower().endswith('.jpg')])
    return total_images

def process_folders(base_path):
    labeled_folder = os.path.join(base_path, 'labeled')
    
    # 'labeled' 폴더 생성 또는 비우기
    if os.path.exists(labeled_folder):
        shutil.rmtree(labeled_folder)
    os.makedirs(labeled_folder)

    total_images = count_total_images(base_path)
    processed_images = 0

    for root, dirs, files in os.walk(base_path):
        if root == base_path or root == labeled_folder:
            continue

        jpg_files = [f for f in files if f.lower().endswith('.jpg')]
        txt_files = [f for f in files if f.lower().endswith('.txt')]

        for jpg_file in jpg_files:
            processed_images += 1
            txt_file = jpg_file[:-4] + '.txt'
            if txt_file in txt_files:
                txt_path = os.path.join(root, txt_file)
                if is_valid_yolo_format(txt_path):
                    jpg_path = os.path.join(root, jpg_file)
                    # jpg 파일 복사
                    shutil.copy2(jpg_path, labeled_folder)
                    # txt 파일 복사
                    shutil.copy2(txt_path, labeled_folder)
                    print(f"Copied {jpg_file} and {txt_file} to labeled folder")
            
            # 진행률 표시
            progress = (processed_images / total_images) * 100
            print(f"\rProgress: {processed_images}/{total_images} ({progress:.2f}%)", end="", flush=True)

    print("\nProcessing complete.")
    print(f"Total images processed: {processed_images}")
    print(f"Images with valid YOLO labels copied: {len(os.listdir(labeled_folder))//2}")

# 실행
base_path = r'\\192.168.100.79/data2/bear/'
process_folders(base_path)
# Out:
# Copied A06_G01_G001_G_200507_4001_10S_000002.087.jpg and A06_G01_G001_G_200507_4001_10S_000002.087.txt to labeled folder
# Progress: 1/71293 (0.00%)Copied A06_G01_G001_G_200507_4001_10S_000003.740.jpg and A06_G01_G001_G_200507_4001_10S_000003.740.txt to labeled folder
# Progress: 2/71293 (0.00%)Copied A06_G01_G001_G_200507_4001_10S_000004.801.jpg and A06_G01_G001_G_200507_4001_10S_000004.801.txt to labeled folder
# Progress: 3/71293 (0.00%)Copied A06_G01_G001_G_200507_4001_10S_000005.662.jpg and A06_G01_G001_G_200507_4001_10S_000005.662.txt to labeled folder
# Progress: 4/71293 (0.01%)Copied A06_G01_G001_G_200507_4001_10S_000006.584.jpg and A06_G01_G001_G_200507_4001_10S_000006.584.txt to labeled folder
# Progress: 5/71293 (0.01%)Copied A06_G01_G001_G_200507_4001_10S_000008.520.jpg and A06_G01_G001_G_200507_4001_10S_000008.520.txt to labeled folder
# Progress: 6/71293 (0.01%)Copied A06_G01_G001_G_200916_4002_10S_000002.596.jpg and A06_G01_G001_G_200916_4002_10S_000002.596.txt to labeled folder
# Progress: 7/71293 (0.01%)Copied A06_G01_G001_G_200916_4002_10S_000004.348.jpg and A06_G01_G001_G_200916_4002_10S_000004.348.txt to labeled folder
# Progress: 8/71293 (0.01%)Copied A06_G01_G001_G_200916_4002_10S_000005.891.jpg and A06_G01_G001_G_200916_4002_10S_000005.891.txt to labeled folder
# Progress: 9/71293 (0.01%)Copied A06_P01_C050_D_210812_0018_12S_000004.743.jpg and A06_P01_C050_D_210812_0018_12S_000004.743.txt to labeled folder
# Progress: 10/71293 (0.01%)Copied A06_P01_C050_D_210812_0018_12S_000008.443.jpg and A06_P01_C050_D_210812_0018_12S_000008.443.txt to labeled folder
# Progress: 11/71293 (0.02%)Copied A06_P01_C050_D_210812_0020_60S_000041.953.jpg and A06_P01_C050_D_210812_0020_60S_000041.953.txt to labeled folder
# Progress: 12/71293 (0.02%)Copied A06_P01_C050_D_210812_0020_60S_000046.250.jpg and A06_P01_C050_D_210812_0020_60S_000046.250.txt to labeled folder
# Progress: 13/71293 (0.02%)Copied A06_P01_C050_D_210812_0020_60S_000046.868.jpg and A06_P01_C050_D_210812_0020_60S_000046.868.txt to labeled folder
# Progress: 14/71293 (0.02%)Copied A06_P01_C050_D_210812_0020_60S_000048.074.jpg and A06_P01_C050_D_210812_0020_60S_000048.074.txt to labeled folder
# Progress: 15/71293 (0.02%)Copied A06_P01_C050_D_210812_0027_59S_000052.372.jpg and A06_P01_C050_D_210812_0027_59S_000052.372.txt to labeled folder
# Progress: 16/71293 (0.02%)Copied A06_P01_C050_D_210812_0027_59S_000059.074.jpg and A06_P01_C050_D_210812_0027_59S_000059.074.txt to labeled folder
# Progress: 17/71293 (0.02%)Copied A06_P01_C050_D_210812_0031_60S_000000.038.jpg and A06_P01_C050_D_210812_0031_60S_000000.038.txt to labeled folder
# Progress: 18/71293 (0.03%)Copied A06_P01_C050_D_210812_0031_60S_000010.232.jpg and A06_P01_C050_D_210812_0031_60S_000010.232.txt to labeled folder
# Progress: 19/71293 (0.03%)Copied A06_P01_C050_D_210812_0031_60S_000017.358.jpg and A06_P01_C050_D_210812_0031_60S_000017.358.txt to labeled folder
# Progress: 20/71293 (0.03%)Copied A06_P01_C050_D_210812_0035_40S_000021.253.jpg and A06_P01_C050_D_210812_0035_40S_000021.253.txt to labeled folder
# Progress: 21/71293 (0.03%)Copied A06_P01_C050_D_210812_0035_40S_000022.218.jpg and A06_P01_C050_D_210812_0035_40S_000022.218.txt to labeled folder
# Progress: 22/71293 (0.03%)Copied A06_P01_C050_D_210812_0035_40S_000023.310.jpg and A06_P01_C050_D_210812_0035_40S_000023.310.txt to labeled folder
# Progress: 23/71293 (0.03%)Copied A06_P01_C050_D_210812_0035_40S_000024.151.jpg and A06_P01_C050_D_210812_0035_40S_000024.151.txt to labeled folder
# Progress: 24/71293 (0.03%)Copied A06_P01_C050_S_210812_0014_11S_000003.287.jpg and A06_P01_C050_S_210812_0014_11S_000003.287.txt to labeled folder
# Progress: 25/71293 (0.04%)Copied A06_P01_C050_S_210812_0014_11S_000005.778.jpg and A06_P01_C050_S_210812_0014_11S_000005.778.txt to labeled folder
# Progress: 26/71293 (0.04%)Copied A06_P01_C050_S_210812_0014_11S_000006.218.jpg and A06_P01_C050_S_210812_0014_11S_000006.218.txt to labeled folder
# Progress: 27/71293 (0.04%)Copied A06_P01_C050_S_210812_0023_28S_000001.644.jpg and A06_P01_C050_S_210812_0023_28S_000001.644.txt to labeled folder
# Progress: 28/71293 (0.04%)Copied A06_P01_C050_S_210812_0023_28S_000003.810.jpg and A06_P01_C050_S_210812_0023_28S_000003.810.txt to labeled folder
# Progress: 29/71293 (0.04%)Copied A06_P01_C050_S_210812_0023_28S_000004.450.jpg and A06_P01_C050_S_210812_0023_28S_000004.450.txt to labeled folder
# Progress: 30/71293 (0.04%)Copied A06_P01_C050_S_210812_0023_28S_000007.020.jpg and A06_P01_C050_S_210812_0023_28S_000007.020.txt to labeled folder
# Progress: 31/71293 (0.04%)Copied A06_P01_C050_S_210812_0023_28S_000008.004.jpg and A06_P01_C050_S_210812_0023_28S_000008.004.txt to labeled folder
# Progress: 32/71293 (0.04%)Copied A06_P01_C050_S_210812_0023_28S_000009.125.jpg and A06_P01_C050_S_210812_0023_28S_000009.125.txt to labeled folder
# Progress: 33/71293 (0.05%)Copied A06_P01_C050_S_210812_0023_28S_000011.263.jpg and A06_P01_C050_S_210812_0023_28S_000011.263.txt to labeled folder
# Progress: 34/71293 (0.05%)Copied A06_P01_C050_S_210812_0023_28S_000013.719.jpg and A06_P01_C050_S_210812_0023_28S_000013.719.txt to labeled folder
# Progress: 35/71293 (0.05%)Copied A06_P01_C050_S_210812_0023_28S_000016.262.jpg and A06_P01_C050_S_210812_0023_28S_000016.262.txt to labeled folder
# Progress: 36/71293 (0.05%)Copied A06_P01_C050_S_210812_0023_28S_000019.394.jpg and A06_P01_C050_S_210812_0023_28S_000019.394.txt to labeled folder
# Progress: 37/71293 (0.05%)Copied A06_P01_C050_S_210812_0023_28S_000020.226.jpg and A06_P01_C050_S_210812_0023_28S_000020.226.txt to labeled folder
# Progress: 38/71293 (0.05%)Copied A06_P01_C050_S_210812_0023_28S_000024.266.jpg and A06_P01_C050_S_210812_0023_28S_000024.266.txt to labeled folder
# Progress: 39/71293 (0.05%)Copied A06_P01_C050_S_210812_0037_19S_000000.901.jpg and A06_P01_C050_S_210812_0037_19S_000000.901.txt to labeled folder
# Progress: 40/71293 (0.06%)Copied A06_P01_C050_S_210812_0060_57S_000050.430.jpg and A06_P01_C050_S_210812_0060_57S_000050.430.txt to labeled folder
# Progress: 41/71293 (0.06%)Copied A06_P01_C050_S_210812_0060_57S_000052.977.jpg and A06_P01_C050_S_210812_0060_57S_000052.977.txt to labeled folder
# Progress: 42/71293 (0.06%)Copied A06_P01_C050_S_210812_0060_57S_000054.237.jpg and A06_P01_C050_S_210812_0060_57S_000054.237.txt to labeled folder
# Progress: 43/71293 (0.06%)Copied A06_P01_C050_S_210812_0060_57S_000055.403.jpg and A06_P01_C050_S_210812_0060_57S_000055.403.txt to labeled folder
# Progress: 44/71293 (0.06%)Copied A06_P01_C050_S_210812_0060_57S_000056.747.jpg and A06_P01_C050_S_210812_0060_57S_000056.747.txt to labeled folder
# Progress: 45/71293 (0.06%)Copied A06_P01_C050_S_210812_0068_59S_000056.776.jpg and A06_P01_C050_S_210812_0068_59S_000056.776.txt to labeled folder
# Progress: 46/71293 (0.06%)Copied A06_P01_C050_S_210812_0075_30S_000026.357.jpg and A06_P01_C050_S_210812_0075_30S_000026.357.txt to labeled folder
# Progress: 47/71293 (0.07%)Copied A06_P01_C050_S_210812_0075_30S_000027.726.jpg and A06_P01_C050_S_210812_0075_30S_000027.726.txt to labeled folder
# Progress: 48/71293 (0.07%)Copied A06_P01_C050_S_210812_0075_30S_000030.135.jpg and A06_P01_C050_S_210812_0075_30S_000030.135.txt to labeled folder
# Progress: 49/71293 (0.07%)Copied A06_P01_C050_S_210812_0075_30S_000030.241.jpg and A06_P01_C050_S_210812_0075_30S_000030.241.txt to labeled folder
# Progress: 50/71293 (0.07%)Copied A06_P01_C050_S_210812_0076_39S_000008.699.jpg and A06_P01_C050_S_210812_0076_39S_000008.699.txt to labeled folder
# Progress: 51/71293 (0.07%)Copied A06_P01_C050_S_210812_0076_39S_000023.299.jpg and A06_P01_C050_S_210812_0076_39S_000023.299.txt to labeled folder
# Progress: 52/71293 (0.07%)Copied A06_P01_C050_S_210812_0076_39S_000032.269.jpg and A06_P01_C050_S_210812_0076_39S_000032.269.txt to labeled folder
# Progress: 53/71293 (0.07%)Copied A06_P01_C050_S_210812_0076_39S_000033.302.jpg and A06_P01_C050_S_210812_0076_39S_000033.302.txt to labeled folder
# Progress: 54/71293 (0.08%)Copied A06_P01_C050_S_210812_0076_39S_000034.490.jpg and A06_P01_C050_S_210812_0076_39S_000034.490.txt to labeled folder
# Progress: 55/71293 (0.08%)Copied A06_P01_C051_S_210812_0004_29S_000015.969.jpg and A06_P01_C051_S_210812_0004_29S_000015.969.txt to labeled folder
# Progress: 56/71293 (0.08%)Copied A06_P01_C051_S_210812_0004_29S_000019.382.jpg and A06_P01_C051_S_210812_0004_29S_000019.382.txt to labeled folder
# Progress: 57/71293 (0.08%)Copied A06_P01_C051_S_210812_0004_29S_000019.630.jpg and A06_P01_C051_S_210812_0004_29S_000019.630.txt to labeled folder
# Progress: 58/71293 (0.08%)Copied A06_P01_C051_S_210812_0004_29S_000021.541.jpg and A06_P01_C051_S_210812_0004_29S_000021.541.txt to labeled folder
# Progress: 59/71293 (0.08%)Copied A06_P01_C051_S_210812_0004_29S_000021.885.jpg and A06_P01_C051_S_210812_0004_29S_000021.885.txt to labeled folder
# Progress: 60/71293 (0.08%)Copied A06_P01_C051_S_210812_0004_29S_000022.311.jpg and A06_P01_C051_S_210812_0004_29S_000022.311.txt to labeled folder
# Progress: 61/71293 (0.09%)Copied A06_P01_C051_S_210812_0005_40S_000000.039.jpg and A06_P01_C051_S_210812_0005_40S_000000.039.txt to labeled folder
# Progress: 62/71293 (0.09%)Copied A06_P01_C051_S_210812_0005_40S_000010.901.jpg and A06_P01_C051_S_210812_0005_40S_000010.901.txt to labeled folder
# Progress: 63/71293 (0.09%)Copied A06_P01_C051_S_210812_0006_39S_000009.088.jpg and A06_P01_C051_S_210812_0006_39S_000009.088.txt to labeled folder
# Progress: 64/71293 (0.09%)Copied A06_P01_C051_S_210812_0006_39S_000015.784.jpg and A06_P01_C051_S_210812_0006_39S_000015.784.txt to labeled folder
# Progress: 65/71293 (0.09%)Copied A06_P01_C051_S_210812_0006_39S_000022.352.jpg and A06_P01_C051_S_210812_0006_39S_000022.352.txt to labeled folder
# Progress: 66/71293 (0.09%)Copied A06_P01_C051_S_210812_0045_58S_000003.203.jpg and A06_P01_C051_S_210812_0045_58S_000003.203.txt to labeled folder
# Progress: 67/71293 (0.09%)Copied A06_P01_C051_S_210812_0045_58S_000005.112.jpg and A06_P01_C051_S_210812_0045_58S_000005.112.txt to labeled folder
# Progress: 68/71293 (0.10%)Copied A06_P08_C050_C_210930_0001_22S_000006.819.jpg and A06_P08_C050_C_210930_0001_22S_000006.819.txt to labeled folder
# Progress: 69/71293 (0.10%)Copied A06_P08_C050_C_210930_0001_22S_000007.174.jpg and A06_P08_C050_C_210930_0001_22S_000007.174.txt to labeled folder
# Progress: 70/71293 (0.10%)Copied A06_P08_C050_C_210930_0001_22S_000007.740.jpg and A06_P08_C050_C_210930_0001_22S_000007.740.txt to labeled folder
# Progress: 71/71293 (0.10%)Copied A06_P08_C050_C_210930_0001_22S_000008.175.jpg and A06_P08_C050_C_210930_0001_22S_000008.175.txt to labeled folder
# Progress: 72/71293 (0.10%)Copied A06_P08_C050_C_210930_0001_22S_000009.178.jpg and A06_P08_C050_C_210930_0001_22S_000009.178.txt to labeled folder
# Progress: 73/71293 (0.10%)Copied A06_P08_C050_C_210930_0001_22S_000009.739.jpg and A06_P08_C050_C_210930_0001_22S_000009.739.txt to labeled folder
# Progress: 74/71293 (0.10%)Copied A06_P08_C050_C_210930_0001_22S_000010.945.jpg and A06_P08_C050_C_210930_0001_22S_000010.945.txt to labeled folder
# Progress: 75/71293 (0.11%)Copied A06_P08_C050_C_210930_0001_22S_000012.472.jpg and A06_P08_C050_C_210930_0001_22S_000012.472.txt to labeled folder
# Progress: 76/71293 (0.11%)Copied A06_P08_C050_C_210930_0001_22S_000015.641.jpg and A06_P08_C050_C_210930_0001_22S_000015.641.txt to labeled folder
# Progress: 77/71293 (0.11%)Copied A06_P08_C050_C_210930_0001_22S_000018.344.jpg and A06_P08_C050_C_210930_0001_22S_000018.344.txt to labeled folder
# Progress: 78/71293 (0.11%)Copied A06_P08_C050_C_210930_0001_22S_000019.611.jpg and A06_P08_C050_C_210930_0001_22S_000019.611.txt to labeled folder
# Progress: 79/71293 (0.11%)Copied A06_P08_C050_C_210930_0001_22S_000021.861.jpg and A06_P08_C050_C_210930_0001_22S_000021.861.txt to labeled folder
# Progress: 80/71293 (0.11%)Copied A06_P08_C050_C_210930_0002_60S_000001.415.jpg and A06_P08_C050_C_210930_0002_60S_000001.415.txt to labeled folder
# Progress: 81/71293 (0.11%)Copied A06_P08_C050_C_210930_0002_60S_000001.658.jpg and A06_P08_C050_C_210930_0002_60S_000001.658.txt to labeled folder
# Progress: 82/71293 (0.12%)Copied A06_P08_C050_C_210930_0002_60S_000002.181.jpg and A06_P08_C050_C_210930_0002_60S_000002.181.txt to labeled folder
# Progress: 83/71293 (0.12%)Copied A06_P08_C050_C_210930_0002_60S_000002.555.jpg and A06_P08_C050_C_210930_0002_60S_000002.555.txt to labeled folder
# Progress: 84/71293 (0.12%)Copied A06_P08_C050_C_210930_0002_60S_000004.876.jpg and A06_P08_C050_C_210930_0002_60S_000004.876.txt to labeled folder
# Progress: 85/71293 (0.12%)Copied A06_P08_C050_C_210930_0002_60S_000005.276.jpg and A06_P08_C050_C_210930_0002_60S_000005.276.txt to labeled folder
# Progress: 86/71293 (0.12%)Copied A06_P08_C050_C_210930_0002_60S_000006.009.jpg and A06_P08_C050_C_210930_0002_60S_000006.009.txt to labeled folder
# Progress: 87/71293 (0.12%)Copied A06_P08_C050_C_210930_0002_60S_000006.949.jpg and A06_P08_C050_C_210930_0002_60S_000006.949.txt to labeled folder
# Progress: 88/71293 (0.12%)Copied A06_P08_C050_C_210930_0002_60S_000007.508.jpg and A06_P08_C050_C_210930_0002_60S_000007.508.txt to labeled folder
# Progress: 89/71293 (0.12%)Copied A06_P08_C050_C_210930_0002_60S_000008.021.jpg and A06_P08_C050_C_210930_0002_60S_000008.021.txt to labeled folder
# Progress: 90/71293 (0.13%)Copied A06_P08_C050_C_210930_0002_60S_000009.212.jpg and A06_P08_C050_C_210930_0002_60S_000009.212.txt to labeled folder
# Progress: 91/71293 (0.13%)Copied A06_P08_C050_C_210930_0002_60S_000009.991.jpg and A06_P08_C050_C_210930_0002_60S_000009.991.txt to labeled folder
# Progress: 92/71293 (0.13%)Copied A06_P08_C050_C_210930_0002_60S_000011.276.jpg and A06_P08_C050_C_210930_0002_60S_000011.276.txt to labeled folder
# Progress: 93/71293 (0.13%)Copied A06_P08_C050_C_210930_0002_60S_000012.507.jpg and A06_P08_C050_C_210930_0002_60S_000012.507.txt to labeled folder
# Progress: 94/71293 (0.13%)Copied A06_P08_C050_C_210930_0002_60S_000013.161.jpg and A06_P08_C050_C_210930_0002_60S_000013.161.txt to labeled folder
# Progress: 95/71293 (0.13%)Copied A06_P08_C050_C_210930_0002_60S_000015.074.jpg and A06_P08_C050_C_210930_0002_60S_000015.074.txt to labeled folder
# Progress: 96/71293 (0.13%)Copied A06_P08_C050_C_210930_0002_60S_000020.730.jpg and A06_P08_C050_C_210930_0002_60S_000020.730.txt to labeled folder
# Progress: 97/71293 (0.14%)Copied A06_P08_C050_C_210930_0002_60S_000021.372.jpg and A06_P08_C050_C_210930_0002_60S_000021.372.txt to labeled folder
# Progress: 98/71293 (0.14%)Copied A06_P08_C050_C_210930_0002_60S_000022.320.jpg and A06_P08_C050_C_210930_0002_60S_000022.320.txt to labeled folder
# Progress: 99/71293 (0.14%)Copied A06_P08_C050_C_210930_0002_60S_000023.495.jpg and A06_P08_C050_C_210930_0002_60S_000023.495.txt to labeled folder
# Progress: 100/71293 (0.14%)Copied A06_P08_C050_C_210930_0002_60S_000026.193.jpg and A06_P08_C050_C_210930_0002_60S_000026.193.txt to labeled folder
# Progress: 101/71293 (0.14%)Copied A06_P08_C050_C_210930_0002_60S_000026.841.jpg and A06_P08_C050_C_210930_0002_60S_000026.841.txt to labeled folder
# Progress: 102/71293 (0.14%)Copied A06_P08_C050_C_210930_0002_60S_000028.539.jpg and A06_P08_C050_C_210930_0002_60S_000028.539.txt to labeled folder
# Progress: 103/71293 (0.14%)Copied A06_P08_C050_C_210930_0002_60S_000030.009.jpg and A06_P08_C050_C_210930_0002_60S_000030.009.txt to labeled folder
# Progress: 104/71293 (0.15%)Copied A06_P08_C050_C_210930_0002_60S_000031.843.jpg and A06_P08_C050_C_210930_0002_60S_000031.843.txt to labeled folder
# Progress: 105/71293 (0.15%)Copied A06_P08_C050_C_210930_0002_60S_000033.601.jpg and A06_P08_C050_C_210930_0002_60S_000033.601.txt to labeled folder
# Progress: 106/71293 (0.15%)Copied A06_P08_C050_C_210930_0002_60S_000034.598.jpg and A06_P08_C050_C_210930_0002_60S_000034.598.txt to labeled folder
# Progress: 107/71293 (0.15%)Copied A06_P08_C050_C_210930_0002_60S_000035.546.jpg and A06_P08_C050_C_210930_0002_60S_000035.546.txt to labeled folder
# Progress: 108/71293 (0.15%)Copied A06_P08_C050_C_210930_0002_60S_000037.113.jpg and A06_P08_C050_C_210930_0002_60S_000037.113.txt to labeled folder
# Progress: 109/71293 (0.15%)Copied A06_P08_C050_C_210930_0002_60S_000038.641.jpg and A06_P08_C050_C_210930_0002_60S_000038.641.txt to labeled folder
# Progress: 110/71293 (0.15%)Copied A06_P08_C050_C_210930_0002_60S_000040.108.jpg and A06_P08_C050_C_210930_0002_60S_000040.108.txt to labeled folder
# Progress: 111/71293 (0.16%)Copied A06_P08_C050_C_210930_0002_60S_000041.355.jpg and A06_P08_C050_C_210930_0002_60S_000041.355.txt to labeled folder
# Progress: 112/71293 (0.16%)Copied A06_P08_C050_C_210930_0002_60S_000041.779.jpg and A06_P08_C050_C_210930_0002_60S_000041.779.txt to labeled folder
# Progress: 113/71293 (0.16%)Copied A06_P08_C050_C_210930_0002_60S_000042.907.jpg and A06_P08_C050_C_210930_0002_60S_000042.907.txt to labeled folder
# Progress: 114/71293 (0.16%)Copied A06_P08_C050_C_210930_0002_60S_000043.209.jpg and A06_P08_C050_C_210930_0002_60S_000043.209.txt to labeled folder
# Progress: 115/71293 (0.16%)Copied A06_P08_C050_C_210930_0002_60S_000043.392.jpg and A06_P08_C050_C_210930_0002_60S_000043.392.txt to labeled folder
# Progress: 116/71293 (0.16%)Copied A06_P08_C050_C_210930_0002_60S_000043.561.jpg and A06_P08_C050_C_210930_0002_60S_000043.561.txt to labeled folder
# Progress: 117/71293 (0.16%)Copied A06_P08_C050_C_210930_0002_60S_000043.889.jpg and A06_P08_C050_C_210930_0002_60S_000043.889.txt to labeled folder
# Progress: 118/71293 (0.17%)Copied A06_P08_C050_C_210930_0002_60S_000044.281.jpg and A06_P08_C050_C_210930_0002_60S_000044.281.txt to labeled folder
# Progress: 119/71293 (0.17%)Copied A06_P08_C050_C_210930_0002_60S_000044.538.jpg and A06_P08_C050_C_210930_0002_60S_000044.538.txt to labeled folder
# Progress: 120/71293 (0.17%)Copied A06_P08_C050_C_210930_0002_60S_000044.742.jpg and A06_P08_C050_C_210930_0002_60S_000044.742.txt to labeled folder
# Progress: 121/71293 (0.17%)Copied A06_P08_C050_C_210930_0002_60S_000045.842.jpg and A06_P08_C050_C_210930_0002_60S_000045.842.txt to labeled folder
# Progress: 122/71293 (0.17%)Copied A06_P08_C050_C_210930_0002_60S_000046.111.jpg and A06_P08_C050_C_210930_0002_60S_000046.111.txt to labeled folder
# Progress: 123/71293 (0.17%)Copied A06_P08_C050_C_210930_0002_60S_000046.911.jpg and A06_P08_C050_C_210930_0002_60S_000046.911.txt to labeled folder
# Progress: 124/71293 (0.17%)Copied A06_P08_C050_C_210930_0002_60S_000052.617.jpg and A06_P08_C050_C_210930_0002_60S_000052.617.txt to labeled folder
# Progress: 125/71293 (0.18%)Copied A06_P08_C050_C_210930_0002_60S_000054.115.jpg and A06_P08_C050_C_210930_0002_60S_000054.115.txt to labeled folder
# Progress: 126/71293 (0.18%)Copied A06_P08_C050_C_210930_0002_60S_000055.073.jpg and A06_P08_C050_C_210930_0002_60S_000055.073.txt to labeled folder
# Progress: 127/71293 (0.18%)Copied A06_P08_C050_C_210930_0002_60S_000055.952.jpg and A06_P08_C050_C_210930_0002_60S_000055.952.txt to labeled folder
# Progress: 128/71293 (0.18%)Copied A06_P08_C050_C_210930_0002_60S_000057.143.jpg and A06_P08_C050_C_210930_0002_60S_000057.143.txt to labeled folder
# Progress: 129/71293 (0.18%)Copied A06_P08_C050_C_210930_0002_60S_000058.775.jpg and A06_P08_C050_C_210930_0002_60S_000058.775.txt to labeled folder
# Progress: 130/71293 (0.18%)Copied A06_P08_C050_C_210930_0002_60S_000059.710.jpg and A06_P08_C050_C_210930_0002_60S_000059.710.txt to labeled folder
# Progress: 131/71293 (0.18%)Copied A06_P08_C050_C_210930_0003_27S_000000.039.jpg and A06_P08_C050_C_210930_0003_27S_000000.039.txt to labeled folder
# Progress: 132/71293 (0.19%)Copied A06_P08_C050_C_210930_0003_27S_000001.873.jpg and A06_P08_C050_C_210930_0003_27S_000001.873.txt to labeled folder
# Progress: 133/71293 (0.19%)Copied A06_P08_C050_C_210930_0003_27S_000002.138.jpg and A06_P08_C050_C_210930_0003_27S_000002.138.txt to labeled folder
# Progress: 134/71293 (0.19%)Copied A06_P08_C050_C_210930_0003_27S_000002.405.jpg and A06_P08_C050_C_210930_0003_27S_000002.405.txt to labeled folder
# Progress: 135/71293 (0.19%)Copied A06_P08_C050_C_210930_0003_27S_000002.805.jpg and A06_P08_C050_C_210930_0003_27S_000002.805.txt to labeled folder
# Progress: 136/71293 (0.19%)Copied A06_P08_C050_C_210930_0003_27S_000003.170.jpg and A06_P08_C050_C_210930_0003_27S_000003.170.txt to labeled folder
# Progress: 137/71293 (0.19%)Copied A06_P08_C050_C_210930_0003_27S_000003.512.jpg and A06_P08_C050_C_210930_0003_27S_000003.512.txt to labeled folder
# Progress: 138/71293 (0.19%)Copied A06_P08_C050_C_210930_0003_27S_000003.618.jpg and A06_P08_C050_C_210930_0003_27S_000003.618.txt to labeled folder
# Progress: 139/71293 (0.19%)Copied A06_P08_C050_C_210930_0003_27S_000005.105.jpg and A06_P08_C050_C_210930_0003_27S_000005.105.txt to labeled folder
# Progress: 140/71293 (0.20%)Copied A06_P08_C050_C_210930_0003_27S_000005.638.jpg and A06_P08_C050_C_210930_0003_27S_000005.638.txt to labeled folder
# Progress: 141/71293 (0.20%)Copied A06_P08_C050_C_210930_0003_27S_000005.945.jpg and A06_P08_C050_C_210930_0003_27S_000005.945.txt to labeled folder
# Progress: 142/71293 (0.20%)Copied A06_P08_C050_C_210930_0003_27S_000006.172.jpg and A06_P08_C050_C_210930_0003_27S_000006.172.txt to labeled folder
# Progress: 143/71293 (0.20%)Copied A06_P08_C050_C_210930_0003_27S_000006.622.jpg and A06_P08_C050_C_210930_0003_27S_000006.622.txt to labeled folder
# Progress: 144/71293 (0.20%)Copied A06_P08_C050_C_210930_0003_27S_000007.078.jpg and A06_P08_C050_C_210930_0003_27S_000007.078.txt to labeled folder
# Progress: 145/71293 (0.20%)Copied A06_P08_C050_C_210930_0003_27S_000007.704.jpg and A06_P08_C050_C_210930_0003_27S_000007.704.txt to labeled folder
# Progress: 146/71293 (0.20%)Copied A06_P08_C050_C_210930_0003_27S_000008.904.jpg and A06_P08_C050_C_210930_0003_27S_000008.904.txt to labeled folder
# Progress: 147/71293 (0.21%)Copied A06_P08_C050_C_210930_0003_27S_000009.153.jpg and A06_P08_C050_C_210930_0003_27S_000009.153.txt to labeled folder
# Progress: 148/71293 (0.21%)Copied A06_P08_C050_C_210930_0003_27S_000010.145.jpg and A06_P08_C050_C_210930_0003_27S_000010.145.txt to labeled folder
# Progress: 149/71293 (0.21%)Copied A06_P08_C050_C_210930_0003_27S_000010.932.jpg and A06_P08_C050_C_210930_0003_27S_000010.932.txt to labeled folder
# Progress: 150/71293 (0.21%)Copied A06_P08_C050_C_210930_0003_27S_000011.755.jpg and A06_P08_C050_C_210930_0003_27S_000011.755.txt to labeled folder
# Progress: 151/71293 (0.21%)Copied A06_P08_C050_C_210930_0003_27S_000011.939.jpg and A06_P08_C050_C_210930_0003_27S_000011.939.txt to labeled folder
# Progress: 152/71293 (0.21%)Copied A06_P08_C050_C_210930_0003_27S_000012.171.jpg and A06_P08_C050_C_210930_0003_27S_000012.171.txt to labeled folder
# Progress: 153/71293 (0.21%)Copied A06_P08_C050_C_210930_0003_27S_000012.451.jpg and A06_P08_C050_C_210930_0003_27S_000012.451.txt to labeled folder
# Progress: 154/71293 (0.22%)Copied A06_P08_C050_C_210930_0003_27S_000012.639.jpg and A06_P08_C050_C_210930_0003_27S_000012.639.txt to labeled folder
# Progress: 155/71293 (0.22%)Copied A06_P08_C050_C_210930_0003_27S_000012.905.jpg and A06_P08_C050_C_210930_0003_27S_000012.905.txt to labeled folder
# Progress: 156/71293 (0.22%)Copied A06_P08_C050_C_210930_0003_27S_000013.206.jpg and A06_P08_C050_C_210930_0003_27S_000013.206.txt to labeled folder
# Progress: 157/71293 (0.22%)Copied A06_P08_C050_C_210930_0003_27S_000013.472.jpg and A06_P08_C050_C_210930_0003_27S_000013.472.txt to labeled folder
# Progress: 158/71293 (0.22%)Copied A06_P08_C050_C_210930_0003_27S_000013.771.jpg and A06_P08_C050_C_210930_0003_27S_000013.771.txt to labeled folder
# Progress: 159/71293 (0.22%)Copied A06_P08_C050_C_210930_0003_27S_000014.171.jpg and A06_P08_C050_C_210930_0003_27S_000014.171.txt to labeled folder
# Progress: 160/71293 (0.22%)Copied A06_P08_C050_C_210930_0003_27S_000014.540.jpg and A06_P08_C050_C_210930_0003_27S_000014.540.txt to labeled folder
# Progress: 161/71293 (0.23%)Copied A06_P08_C050_C_210930_0003_27S_000014.837.jpg and A06_P08_C050_C_210930_0003_27S_000014.837.txt to labeled folder
# Progress: 162/71293 (0.23%)Copied A06_P08_C050_C_210930_0003_27S_000015.096.jpg and A06_P08_C050_C_210930_0003_27S_000015.096.txt to labeled folder
# Progress: 163/71293 (0.23%)Copied A06_P08_C050_C_210930_0003_27S_000023.405.jpg and A06_P08_C050_C_210930_0003_27S_000023.405.txt to labeled folder
# Progress: 164/71293 (0.23%)Copied A06_P08_C050_C_210930_0003_27S_000023.839.jpg and A06_P08_C050_C_210930_0003_27S_000023.839.txt to labeled folder
# Progress: 165/71293 (0.23%)Copied A06_P08_C050_C_210930_0003_27S_000024.342.jpg and A06_P08_C050_C_210930_0003_27S_000024.342.txt to labeled folder
# Progress: 166/71293 (0.23%)Copied A06_P08_C050_C_210930_0003_27S_000024.804.jpg and A06_P08_C050_C_210930_0003_27S_000024.804.txt to labeled folder
# Progress: 167/71293 (0.23%)Copied A06_P08_C050_C_210930_0003_27S_000025.229.jpg and A06_P08_C050_C_210930_0003_27S_000025.229.txt to labeled folder
# Progress: 168/71293 (0.24%)Copied A06_P08_C050_C_210930_0003_27S_000025.612.jpg and A06_P08_C050_C_210930_0003_27S_000025.612.txt to labeled folder
# Progress: 169/71293 (0.24%)Copied A06_P08_C050_C_210930_0003_27S_000026.737.jpg and A06_P08_C050_C_210930_0003_27S_000026.737.txt to labeled folder
# Progress: 170/71293 (0.24%)Copied A06_P08_C050_C_210930_0004_10S_000000.204.jpg and A06_P08_C050_C_210930_0004_10S_000000.204.txt to labeled folder
# Progress: 171/71293 (0.24%)Copied A06_P08_C050_C_210930_0004_10S_000000.771.jpg and A06_P08_C050_C_210930_0004_10S_000000.771.txt to labeled folder
# Progress: 172/71293 (0.24%)Copied A06_P08_C050_C_210930_0004_10S_000001.210.jpg and A06_P08_C050_C_210930_0004_10S_000001.210.txt to labeled folder
# Progress: 173/71293 (0.24%)Copied A06_P08_C050_C_210930_0004_10S_000001.577.jpg and A06_P08_C050_C_210930_0004_10S_000001.577.txt to labeled folder
# Progress: 174/71293 (0.24%)Copied A06_P08_C050_C_210930_0004_10S_000001.867.jpg and A06_P08_C050_C_210930_0004_10S_000001.867.txt to labeled folder
# Progress: 175/71293 (0.25%)Copied A06_P08_C050_C_210930_0004_10S_000002.209.jpg and A06_P08_C050_C_210930_0004_10S_000002.209.txt to labeled folder
# Progress: 176/71293 (0.25%)Copied A06_P08_C050_C_210930_0004_10S_000002.952.jpg and A06_P08_C050_C_210930_0004_10S_000002.952.txt to labeled folder
# Progress: 177/71293 (0.25%)Copied A06_P08_C050_C_210930_0004_10S_000003.072.jpg and A06_P08_C050_C_210930_0004_10S_000003.072.txt to labeled folder
# Progress: 178/71293 (0.25%)Copied A06_P08_C050_C_210930_0005_60S_000004.378.jpg and A06_P08_C050_C_210930_0005_60S_000004.378.txt to labeled folder
# Progress: 179/71293 (0.25%)Copied A06_P08_C050_C_210930_0005_60S_000004.806.jpg and A06_P08_C050_C_210930_0005_60S_000004.806.txt to labeled folder
# Progress: 180/71293 (0.25%)Copied A06_P08_C050_C_210930_0005_60S_000005.174.jpg and A06_P08_C050_C_210930_0005_60S_000005.174.txt to labeled folder
# Progress: 181/71293 (0.25%)Copied A06_P08_C050_C_210930_0005_60S_000006.031.jpg and A06_P08_C050_C_210930_0005_60S_000006.031.txt to labeled folder
# Progress: 182/71293 (0.26%)Copied A06_P08_C050_C_210930_0005_60S_000006.407.jpg and A06_P08_C050_C_210930_0005_60S_000006.407.txt to labeled folder
# Progress: 183/71293 (0.26%)Copied A06_P08_C050_C_210930_0005_60S_000006.808.jpg and A06_P08_C050_C_210930_0005_60S_000006.808.txt to labeled folder
# Progress: 184/71293 (0.26%)Copied A06_P08_C050_C_210930_0005_60S_000007.578.jpg and A06_P08_C050_C_210930_0005_60S_000007.578.txt to labeled folder
# Progress: 185/71293 (0.26%)Copied A06_P08_C050_C_210930_0005_60S_000008.219.jpg and A06_P08_C050_C_210930_0005_60S_000008.219.txt to labeled folder
# Progress: 186/71293 (0.26%)Copied A06_P08_C050_C_210930_0005_60S_000008.614.jpg and A06_P08_C050_C_210930_0005_60S_000008.614.txt to labeled folder
# Progress: 187/71293 (0.26%)Copied A06_P08_C050_C_210930_0005_60S_000008.996.jpg and A06_P08_C050_C_210930_0005_60S_000008.996.txt to labeled folder
# Progress: 188/71293 (0.26%)Copied A06_P08_C050_C_210930_0005_60S_000009.540.jpg and A06_P08_C050_C_210930_0005_60S_000009.540.txt to labeled folder
# Progress: 189/71293 (0.27%)Copied A06_P08_C050_C_210930_0005_60S_000012.472.jpg and A06_P08_C050_C_210930_0005_60S_000012.472.txt to labeled folder
# Progress: 190/71293 (0.27%)Copied A06_P08_C050_C_210930_0005_60S_000013.704.jpg and A06_P08_C050_C_210930_0005_60S_000013.704.txt to labeled folder
# Progress: 191/71293 (0.27%)Copied A06_P08_C050_C_210930_0005_60S_000015.339.jpg and A06_P08_C050_C_210930_0005_60S_000015.339.txt to labeled folder
# Progress: 192/71293 (0.27%)Copied A06_P08_C050_C_210930_0005_60S_000015.731.jpg and A06_P08_C050_C_210930_0005_60S_000015.731.txt to labeled folder
# Progress: 193/71293 (0.27%)Copied A06_P08_C050_C_210930_0005_60S_000015.970.jpg and A06_P08_C050_C_210930_0005_60S_000015.970.txt to labeled folder
# Progress: 194/71293 (0.27%)Copied A06_P08_C050_C_210930_0005_60S_000016.234.jpg and A06_P08_C050_C_210930_0005_60S_000016.234.txt to labeled folder
# Progress: 195/71293 (0.27%)Copied A06_P08_C050_C_210930_0005_60S_000016.700.jpg and A06_P08_C050_C_210930_0005_60S_000016.700.txt to labeled folder
# Progress: 196/71293 (0.27%)Copied A06_P08_C050_C_210930_0005_60S_000017.421.jpg and A06_P08_C050_C_210930_0005_60S_000017.421.txt to labeled folder
# Progress: 197/71293 (0.28%)Copied A06_P08_C050_C_210930_0005_60S_000017.846.jpg and A06_P08_C050_C_210930_0005_60S_000017.846.txt to labeled folder
# Progress: 198/71293 (0.28%)Copied A06_P08_C050_C_210930_0005_60S_000018.415.jpg and A06_P08_C050_C_210930_0005_60S_000018.415.txt to labeled folder
# Progress: 199/71293 (0.28%)Copied A06_P08_C050_C_210930_0005_60S_000018.886.jpg and A06_P08_C050_C_210930_0005_60S_000018.886.txt to labeled folder
# Progress: 200/71293 (0.28%)Copied A06_P08_C050_C_210930_0005_60S_000019.171.jpg and A06_P08_C050_C_210930_0005_60S_000019.171.txt to labeled folder
# Progress: 201/71293 (0.28%)Copied A06_P08_C050_C_210930_0005_60S_000019.700.jpg and A06_P08_C050_C_210930_0005_60S_000019.700.txt to labeled folder
# Progress: 202/71293 (0.28%)Copied A06_P08_C050_C_210930_0005_60S_000019.954.jpg and A06_P08_C050_C_210930_0005_60S_000019.954.txt to labeled folder
# Progress: 203/71293 (0.28%)Copied A06_P08_C050_C_210930_0005_60S_000020.402.jpg and A06_P08_C050_C_210930_0005_60S_000020.402.txt to labeled folder
# Progress: 204/71293 (0.29%)Copied A06_P08_C050_C_210930_0005_60S_000026.526.jpg and A06_P08_C050_C_210930_0005_60S_000026.526.txt to labeled folder
# Progress: 205/71293 (0.29%)Copied A06_P08_C050_C_210930_0005_60S_000027.294.jpg and A06_P08_C050_C_210930_0005_60S_000027.294.txt to labeled folder
# Progress: 206/71293 (0.29%)Copied A06_P08_C050_C_210930_0005_60S_000027.851.jpg and A06_P08_C050_C_210930_0005_60S_000027.851.txt to labeled folder
# Progress: 207/71293 (0.29%)Copied A06_P08_C050_C_210930_0005_60S_000029.279.jpg and A06_P08_C050_C_210930_0005_60S_000029.279.txt to labeled folder
# Progress: 208/71293 (0.29%)Copied A06_P08_C050_C_210930_0005_60S_000037.136.jpg and A06_P08_C050_C_210930_0005_60S_000037.136.txt to labeled folder
# Progress: 209/71293 (0.29%)Copied A06_P08_C050_C_210930_0005_60S_000040.169.jpg and A06_P08_C050_C_210930_0005_60S_000040.169.txt to labeled folder
# Progress: 210/71293 (0.29%)Copied A06_P08_C050_C_210930_0005_60S_000043.412.jpg and A06_P08_C050_C_210930_0005_60S_000043.412.txt to labeled folder
# Progress: 211/71293 (0.30%)Copied A06_P08_C050_C_210930_0005_60S_000047.192.jpg and A06_P08_C050_C_210930_0005_60S_000047.192.txt to labeled folder
# Progress: 212/71293 (0.30%)Copied A06_P08_C050_C_210930_0005_60S_000048.030.jpg and A06_P08_C050_C_210930_0005_60S_000048.030.txt to labeled folder
# Progress: 213/71293 (0.30%)Copied A06_P08_C050_C_210930_0005_60S_000048.489.jpg and A06_P08_C050_C_210930_0005_60S_000048.489.txt to labeled folder
# Progress: 214/71293 (0.30%)Copied A06_P08_C050_C_210930_0005_60S_000053.276.jpg and A06_P08_C050_C_210930_0005_60S_000053.276.txt to labeled folder
# Progress: 215/71293 (0.30%)Copied A06_P08_C050_C_210930_0005_60S_000054.545.jpg and A06_P08_C050_C_210930_0005_60S_000054.545.txt to labeled folder
# Progress: 216/71293 (0.30%)Copied A06_P08_C050_C_210930_0005_60S_000055.036.jpg and A06_P08_C050_C_210930_0005_60S_000055.036.txt to labeled folder
# Progress: 217/71293 (0.30%)Copied A06_P08_C050_C_210930_0005_60S_000059.077.jpg and A06_P08_C050_C_210930_0005_60S_000059.077.txt to labeled folder
# Progress: 218/71293 (0.31%)Copied A06_P08_C050_C_210930_0006_60S_000000.038.jpg and A06_P08_C050_C_210930_0006_60S_000000.038.txt to labeled folder
# Progress: 219/71293 (0.31%)Copied A06_P08_C050_C_210930_0006_60S_000000.341.jpg and A06_P08_C050_C_210930_0006_60S_000000.341.txt to labeled folder
# Progress: 220/71293 (0.31%)Copied A06_P08_C050_C_210930_0006_60S_000000.841.jpg and A06_P08_C050_C_210930_0006_60S_000000.841.txt to labeled folder
# Progress: 221/71293 (0.31%)Copied A06_P08_C050_C_210930_0006_60S_000001.262.jpg and A06_P08_C050_C_210930_0006_60S_000001.262.txt to labeled folder
# Progress: 222/71293 (0.31%)Copied A06_P08_C050_C_210930_0006_60S_000002.649.jpg and A06_P08_C050_C_210930_0006_60S_000002.649.txt to labeled folder
# Progress: 223/71293 (0.31%)Copied A06_P08_C050_C_210930_0006_60S_000003.436.jpg and A06_P08_C050_C_210930_0006_60S_000003.436.txt to labeled folder
# Progress: 224/71293 (0.31%)Copied A06_P08_C050_C_210930_0006_60S_000003.886.jpg and A06_P08_C050_C_210930_0006_60S_000003.886.txt to labeled folder
# Progress: 225/71293 (0.32%)Copied A06_P08_C050_C_210930_0006_60S_000004.276.jpg and A06_P08_C050_C_210930_0006_60S_000004.276.txt to labeled folder
# Progress: 226/71293 (0.32%)Copied A06_P08_C050_C_210930_0006_60S_000004.779.jpg and A06_P08_C050_C_210930_0006_60S_000004.779.txt to labeled folder
# Progress: 227/71293 (0.32%)Copied A06_P08_C050_C_210930_0006_60S_000005.176.jpg and A06_P08_C050_C_210930_0006_60S_000005.176.txt to labeled folder
# Progress: 228/71293 (0.32%)Copied A06_P08_C050_C_210930_0006_60S_000005.532.jpg and A06_P08_C050_C_210930_0006_60S_000005.532.txt to labeled folder
# Progress: 229/71293 (0.32%)Copied A06_P08_C050_C_210930_0006_60S_000006.611.jpg and A06_P08_C050_C_210930_0006_60S_000006.611.txt to labeled folder
# Progress: 230/71293 (0.32%)Copied A06_P08_C050_C_210930_0006_60S_000011.364.jpg and A06_P08_C050_C_210930_0006_60S_000011.364.txt to labeled folder
# Progress: 231/71293 (0.32%)Copied A06_P08_C050_C_210930_0006_60S_000012.038.jpg and A06_P08_C050_C_210930_0006_60S_000012.038.txt to labeled folder
# Progress: 232/71293 (0.33%)Copied A06_P08_C050_C_210930_0006_60S_000012.459.jpg and A06_P08_C050_C_210930_0006_60S_000012.459.txt to labeled folder
# Progress: 233/71293 (0.33%)Copied A06_P08_C050_C_210930_0006_60S_000012.956.jpg and A06_P08_C050_C_210930_0006_60S_000012.956.txt to labeled folder
# Progress: 234/71293 (0.33%)Copied A06_P08_C050_C_210930_0006_60S_000013.266.jpg and A06_P08_C050_C_210930_0006_60S_000013.266.txt to labeled folder
# Progress: 235/71293 (0.33%)Copied A06_P08_C050_C_210930_0006_60S_000014.621.jpg and A06_P08_C050_C_210930_0006_60S_000014.621.txt to labeled folder
# Progress: 236/71293 (0.33%)Copied A06_P08_C050_C_210930_0006_60S_000015.040.jpg and A06_P08_C050_C_210930_0006_60S_000015.040.txt to labeled folder
# Progress: 237/71293 (0.33%)Copied A06_P08_C050_C_210930_0006_60S_000016.795.jpg and A06_P08_C050_C_210930_0006_60S_000016.795.txt to labeled folder
# Progress: 238/71293 (0.33%)Copied A06_P08_C050_C_210930_0006_60S_000017.910.jpg and A06_P08_C050_C_210930_0006_60S_000017.910.txt to labeled folder
# Progress: 239/71293 (0.34%)Copied A06_P08_C050_C_210930_0006_60S_000018.577.jpg and A06_P08_C050_C_210930_0006_60S_000018.577.txt to labeled folder
# Progress: 240/71293 (0.34%)Copied A06_P08_C050_C_210930_0006_60S_000020.078.jpg and A06_P08_C050_C_210930_0006_60S_000020.078.txt to labeled folder
# Progress: 241/71293 (0.34%)Copied A06_P08_C050_C_210930_0006_60S_000022.083.jpg and A06_P08_C050_C_210930_0006_60S_000022.083.txt to labeled folder
# Progress: 242/71293 (0.34%)Copied A06_P08_C050_C_210930_0006_60S_000023.507.jpg and A06_P08_C050_C_210930_0006_60S_000023.507.txt to labeled folder
# Progress: 243/71293 (0.34%)Copied A06_P08_C050_C_210930_0006_60S_000023.942.jpg and A06_P08_C050_C_210930_0006_60S_000023.942.txt to labeled folder
# Progress: 244/71293 (0.34%)Copied A06_P08_C050_C_210930_0006_60S_000024.750.jpg and A06_P08_C050_C_210930_0006_60S_000024.750.txt to labeled folder
# Progress: 245/71293 (0.34%)Copied A06_P08_C050_C_210930_0006_60S_000025.378.jpg and A06_P08_C050_C_210930_0006_60S_000025.378.txt to labeled folder
# Progress: 246/71293 (0.35%)Copied A06_P08_C050_C_210930_0006_60S_000025.815.jpg and A06_P08_C050_C_210930_0006_60S_000025.815.txt to labeled folder
# Progress: 247/71293 (0.35%)Copied A06_P08_C050_C_210930_0006_60S_000026.431.jpg and A06_P08_C050_C_210930_0006_60S_000026.431.txt to labeled folder
# Progress: 248/71293 (0.35%)Copied A06_P08_C050_C_210930_0006_60S_000027.218.jpg and A06_P08_C050_C_210930_0006_60S_000027.218.txt to labeled folder
# Progress: 249/71293 (0.35%)Copied A06_P08_C050_C_210930_0006_60S_000028.547.jpg and A06_P08_C050_C_210930_0006_60S_000028.547.txt to labeled folder
# Progress: 250/71293 (0.35%)Copied A06_P08_C050_C_210930_0006_60S_000028.828.jpg and A06_P08_C050_C_210930_0006_60S_000028.828.txt to labeled folder
# Progress: 251/71293 (0.35%)Copied A06_P08_C050_C_210930_0006_60S_000029.172.jpg and A06_P08_C050_C_210930_0006_60S_000029.172.txt to labeled folder
# Progress: 252/71293 (0.35%)Copied A06_P08_C050_C_210930_0006_60S_000029.603.jpg and A06_P08_C050_C_210930_0006_60S_000029.603.txt to labeled folder
# Progress: 253/71293 (0.35%)Copied A06_P08_C050_C_210930_0006_60S_000030.097.jpg and A06_P08_C050_C_210930_0006_60S_000030.097.txt to labeled folder
# Progress: 254/71293 (0.36%)Copied A06_P08_C050_C_210930_0006_60S_000030.688.jpg and A06_P08_C050_C_210930_0006_60S_000030.688.txt to labeled folder
# Progress: 255/71293 (0.36%)Copied A06_P08_C050_C_210930_0006_60S_000031.151.jpg and A06_P08_C050_C_210930_0006_60S_000031.151.txt to labeled folder
# Progress: 256/71293 (0.36%)Copied A06_P08_C050_C_210930_0006_60S_000031.740.jpg and A06_P08_C050_C_210930_0006_60S_000031.740.txt to labeled folder
# Progress: 257/71293 (0.36%)Copied A06_P08_C050_C_210930_0006_60S_000032.393.jpg and A06_P08_C050_C_210930_0006_60S_000032.393.txt to labeled folder
# Progress: 258/71293 (0.36%)Copied A06_P08_C050_C_210930_0006_60S_000033.147.jpg and A06_P08_C050_C_210930_0006_60S_000033.147.txt to labeled folder
# Progress: 259/71293 (0.36%)Copied A06_P08_C050_C_210930_0006_60S_000033.793.jpg and A06_P08_C050_C_210930_0006_60S_000033.793.txt to labeled folder
# Progress: 260/71293 (0.36%)Copied A06_P08_C050_C_210930_0006_60S_000033.987.jpg and A06_P08_C050_C_210930_0006_60S_000033.987.txt to labeled folder
# Progress: 261/71293 (0.37%)Copied A06_P08_C050_C_210930_0006_60S_000034.388.jpg and A06_P08_C050_C_210930_0006_60S_000034.388.txt to labeled folder
# Progress: 262/71293 (0.37%)Copied A06_P08_C050_C_210930_0006_60S_000034.627.jpg and A06_P08_C050_C_210930_0006_60S_000034.627.txt to labeled folder
# Progress: 263/71293 (0.37%)Copied A06_P08_C050_C_210930_0006_60S_000035.209.jpg and A06_P08_C050_C_210930_0006_60S_000035.209.txt to labeled folder
# Progress: 264/71293 (0.37%)Copied A06_P08_C050_C_210930_0006_60S_000036.084.jpg and A06_P08_C050_C_210930_0006_60S_000036.084.txt to labeled folder
# Progress: 265/71293 (0.37%)Copied A06_P08_C050_C_210930_0006_60S_000036.496.jpg and A06_P08_C050_C_210930_0006_60S_000036.496.txt to labeled folder
# Progress: 266/71293 (0.37%)Copied A06_P08_C050_C_210930_0006_60S_000038.953.jpg and A06_P08_C050_C_210930_0006_60S_000038.953.txt to labeled folder
# Progress: 267/71293 (0.37%)Copied A06_P08_C050_C_210930_0006_60S_000039.553.jpg and A06_P08_C050_C_210930_0006_60S_000039.553.txt to labeled folder
# Progress: 268/71293 (0.38%)Copied A06_P08_C050_C_210930_0006_60S_000040.112.jpg and A06_P08_C050_C_210930_0006_60S_000040.112.txt to labeled folder
# Progress: 269/71293 (0.38%)Copied A06_P08_C050_C_210930_0006_60S_000040.942.jpg and A06_P08_C050_C_210930_0006_60S_000040.942.txt to labeled folder
# Progress: 270/71293 (0.38%)Copied A06_P08_C050_C_210930_0006_60S_000041.497.jpg and A06_P08_C050_C_210930_0006_60S_000041.497.txt to labeled folder
# Progress: 271/71293 (0.38%)Copied A06_P08_C050_C_210930_0006_60S_000042.637.jpg and A06_P08_C050_C_210930_0006_60S_000042.637.txt to labeled folder
# Progress: 272/71293 (0.38%)Copied A06_P08_C050_C_210930_0006_60S_000043.177.jpg and A06_P08_C050_C_210930_0006_60S_000043.177.txt to labeled folder
# Progress: 273/71293 (0.38%)Copied A06_P08_C050_C_210930_0006_60S_000043.976.jpg and A06_P08_C050_C_210930_0006_60S_000043.976.txt to labeled folder
# Progress: 274/71293 (0.38%)Copied A06_P08_C050_C_210930_0006_60S_000044.862.jpg and A06_P08_C050_C_210930_0006_60S_000044.862.txt to labeled folder
# Progress: 275/71293 (0.39%)Copied A06_P08_C050_C_210930_0006_60S_000045.982.jpg and A06_P08_C050_C_210930_0006_60S_000045.982.txt to labeled folder
# Progress: 276/71293 (0.39%)Copied A06_P08_C050_C_210930_0006_60S_000048.000.jpg and A06_P08_C050_C_210930_0006_60S_000048.000.txt to labeled folder
# Progress: 277/71293 (0.39%)Copied A06_P08_C050_C_210930_0006_60S_000048.439.jpg and A06_P08_C050_C_210930_0006_60S_000048.439.txt to labeled folder
# Progress: 278/71293 (0.39%)Copied A06_P08_C050_C_210930_0006_60S_000050.321.jpg and A06_P08_C050_C_210930_0006_60S_000050.321.txt to labeled folder
# Progress: 279/71293 (0.39%)Copied A06_P08_C050_C_210930_0006_60S_000050.684.jpg and A06_P08_C050_C_210930_0006_60S_000050.684.txt to labeled folder
# Progress: 280/71293 (0.39%)Copied A06_P08_C050_C_210930_0006_60S_000051.066.jpg and A06_P08_C050_C_210930_0006_60S_000051.066.txt to labeled folder
# Progress: 281/71293 (0.39%)Copied A06_P08_C050_C_210930_0006_60S_000051.453.jpg and A06_P08_C050_C_210930_0006_60S_000051.453.txt to labeled folder
# Progress: 282/71293 (0.40%)Copied A06_P08_C050_C_210930_0006_60S_000054.110.jpg and A06_P08_C050_C_210930_0006_60S_000054.110.txt to labeled folder
# Progress: 283/71293 (0.40%)Copied A06_P08_C050_C_210930_0006_60S_000054.762.jpg and A06_P08_C050_C_210930_0006_60S_000054.762.txt to labeled folder
# Progress: 284/71293 (0.40%)Copied A06_P08_C050_C_210930_0006_60S_000055.795.jpg and A06_P08_C050_C_210930_0006_60S_000055.795.txt to labeled folder
# Progress: 285/71293 (0.40%)Copied A06_P08_C050_C_210930_0006_60S_000056.838.jpg and A06_P08_C050_C_210930_0006_60S_000056.838.txt to labeled folder
# Progress: 286/71293 (0.40%)Copied A06_P08_C050_C_210930_0006_60S_000057.879.jpg and A06_P08_C050_C_210930_0006_60S_000057.879.txt to labeled folder
# Progress: 287/71293 (0.40%)Copied A06_P08_C050_C_210930_0006_60S_000058.697.jpg and A06_P08_C050_C_210930_0006_60S_000058.697.txt to labeled folder
# Progress: 288/71293 (0.40%)Copied A06_P08_C050_C_210930_0006_60S_000059.192.jpg and A06_P08_C050_C_210930_0006_60S_000059.192.txt to labeled folder
# Progress: 289/71293 (0.41%)Copied A06_P08_C050_C_210930_0007_60S_000000.039.jpg and A06_P08_C050_C_210930_0007_60S_000000.039.txt to labeled folder
# Progress: 290/71293 (0.41%)Copied A06_P08_C050_C_210930_0007_60S_000002.622.jpg and A06_P08_C050_C_210930_0007_60S_000002.622.txt to labeled folder
# Progress: 291/71293 (0.41%)Copied A06_P08_C050_C_210930_0007_60S_000003.628.jpg and A06_P08_C050_C_210930_0007_60S_000003.628.txt to labeled folder
# Progress: 292/71293 (0.41%)Copied A06_P08_C050_C_210930_0007_60S_000004.087.jpg and A06_P08_C050_C_210930_0007_60S_000004.087.txt to labeled folder
# Progress: 293/71293 (0.41%)Copied A06_P08_C050_C_210930_0007_60S_000004.984.jpg and A06_P08_C050_C_210930_0007_60S_000004.984.txt to labeled folder
# Progress: 294/71293 (0.41%)Copied A06_P08_C050_C_210930_0007_60S_000005.554.jpg and A06_P08_C050_C_210930_0007_60S_000005.554.txt to labeled folder
# Progress: 295/71293 (0.41%)Copied A06_P08_C050_C_210930_0007_60S_000007.513.jpg and A06_P08_C050_C_210930_0007_60S_000007.513.txt to labeled folder
# Progress: 296/71293 (0.42%)Copied A06_P08_C050_C_210930_0007_60S_000007.950.jpg and A06_P08_C050_C_210930_0007_60S_000007.950.txt to labeled folder
# Progress: 297/71293 (0.42%)Copied A06_P08_C050_C_210930_0007_60S_000008.423.jpg and A06_P08_C050_C_210930_0007_60S_000008.423.txt to labeled folder
# Progress: 298/71293 (0.42%)Copied A06_P08_C050_C_210930_0007_60S_000008.909.jpg and A06_P08_C050_C_210930_0007_60S_000008.909.txt to labeled folder
# Progress: 299/71293 (0.42%)Copied A06_P08_C050_C_210930_0007_60S_000009.407.jpg and A06_P08_C050_C_210930_0007_60S_000009.407.txt to labeled folder
# Progress: 300/71293 (0.42%)Copied A06_P08_C050_C_210930_0007_60S_000009.877.jpg and A06_P08_C050_C_210930_0007_60S_000009.877.txt to labeled folder
# Progress: 301/71293 (0.42%)Copied A06_P08_C050_C_210930_0007_60S_000010.167.jpg and A06_P08_C050_C_210930_0007_60S_000010.167.txt to labeled folder
# Progress: 302/71293 (0.42%)Copied A06_P08_C050_C_210930_0007_60S_000010.416.jpg and A06_P08_C050_C_210930_0007_60S_000010.416.txt to labeled folder
# Progress: 303/71293 (0.43%)Copied A06_P08_C050_C_210930_0007_60S_000010.866.jpg and A06_P08_C050_C_210930_0007_60S_000010.866.txt to labeled folder
# Progress: 304/71293 (0.43%)Copied A06_P08_C050_C_210930_0007_60S_000011.257.jpg and A06_P08_C050_C_210930_0007_60S_000011.257.txt to labeled folder
# Progress: 305/71293 (0.43%)Copied A06_P08_C050_C_210930_0007_60S_000012.588.jpg and A06_P08_C050_C_210930_0007_60S_000012.588.txt to labeled folder
# Progress: 306/71293 (0.43%)Copied A06_P08_C050_C_210930_0007_60S_000014.470.jpg and A06_P08_C050_C_210930_0007_60S_000014.470.txt to labeled folder
# Progress: 307/71293 (0.43%)Copied A06_P08_C050_C_210930_0007_60S_000018.872.jpg and A06_P08_C050_C_210930_0007_60S_000018.872.txt to labeled folder
# Progress: 308/71293 (0.43%)Copied A06_P08_C050_C_210930_0007_60S_000019.596.jpg and A06_P08_C050_C_210930_0007_60S_000019.596.txt to labeled folder
# Progress: 309/71293 (0.43%)Copied A06_P08_C050_C_210930_0007_60S_000020.234.jpg and A06_P08_C050_C_210930_0007_60S_000020.234.txt to labeled folder
# Progress: 310/71293 (0.43%)Copied A06_P08_C050_C_210930_0007_60S_000021.077.jpg and A06_P08_C050_C_210930_0007_60S_000021.077.txt to labeled folder
# Progress: 311/71293 (0.44%)Copied A06_P08_C050_C_210930_0007_60S_000023.130.jpg and A06_P08_C050_C_210930_0007_60S_000023.130.txt to labeled folder
# Progress: 312/71293 (0.44%)Copied A06_P08_C050_C_210930_0007_60S_000023.557.jpg and A06_P08_C050_C_210930_0007_60S_000023.557.txt to labeled folder
# Progress: 313/71293 (0.44%)Copied A06_P08_C050_C_210930_0007_60S_000024.656.jpg and A06_P08_C050_C_210930_0007_60S_000024.656.txt to labeled folder
# Progress: 314/71293 (0.44%)Copied A06_P08_C050_C_210930_0007_60S_000026.004.jpg and A06_P08_C050_C_210930_0007_60S_000026.004.txt to labeled folder
# Progress: 315/71293 (0.44%)Copied A06_P08_C050_C_210930_0007_60S_000028.170.jpg and A06_P08_C050_C_210930_0007_60S_000028.170.txt to labeled folder
# Progress: 316/71293 (0.44%)Copied A06_P08_C050_C_210930_0007_60S_000028.872.jpg and A06_P08_C050_C_210930_0007_60S_000028.872.txt to labeled folder
# Progress: 317/71293 (0.44%)Copied A06_P08_C050_C_210930_0007_60S_000029.928.jpg and A06_P08_C050_C_210930_0007_60S_000029.928.txt to labeled folder
# Progress: 318/71293 (0.45%)Copied A06_P08_C050_C_210930_0007_60S_000031.084.jpg and A06_P08_C050_C_210930_0007_60S_000031.084.txt to labeled folder
# Progress: 319/71293 (0.45%)Copied A06_P08_C050_C_210930_0007_60S_000031.846.jpg and A06_P08_C050_C_210930_0007_60S_000031.846.txt to labeled folder
# Progress: 320/71293 (0.45%)Copied A06_P08_C050_C_210930_0007_60S_000032.285.jpg and A06_P08_C050_C_210930_0007_60S_000032.285.txt to labeled folder
# Progress: 321/71293 (0.45%)Copied A06_P08_C050_C_210930_0007_60S_000032.990.jpg and A06_P08_C050_C_210930_0007_60S_000032.990.txt to labeled folder
# Progress: 322/71293 (0.45%)Copied A06_P08_C050_C_210930_0007_60S_000033.783.jpg and A06_P08_C050_C_210930_0007_60S_000033.783.txt to labeled folder
# Progress: 323/71293 (0.45%)Copied A06_P08_C050_C_210930_0007_60S_000035.458.jpg and A06_P08_C050_C_210930_0007_60S_000035.458.txt to labeled folder
# Progress: 324/71293 (0.45%)Copied A06_P08_C050_C_210930_0007_60S_000035.917.jpg and A06_P08_C050_C_210930_0007_60S_000035.917.txt to labeled folder
# ...
# Progress: 12163/71293 (17.06%)Copied A06_P16_C051_C_211127_3175_20S_000017.005.jpg and A06_P16_C051_C_211127_3175_20S_000017.005.txt to labeled folder
# Progress: 12164/71293 (17.06%)Copied A06_P16_C051_C_211127_3175_20S_000017.008.jpg and A06_P16_C051_C_211127_3175_20S_000017.008.txt to labeled folder
# Progress: 12165/71293 (17.06%)Copied A06_P16_C051_C_211127_3175_20S_000017.020.jpg and A06_P16_C051_C_211127_3175_20S_000017.020.txt to labeled folder
# Progress: 12166/71293 (17.06%)Copied A06_P16_C051_C_211127_3175_20S_000018.019.jpg and A06_P16_C051_C_211127_3175_20S_000018.019.txt to labeled folder
# Progress: 12167/71293 (17.07%)Copied A06_P16_C051_C_211127_3176_10S_000000.002.jpg and A06_P16_C051_C_211127_3176_10S_000000.002.txt to labeled folder
# Progress: 12168/71293 (17.07%)Copied A06_P16_C051_C_211127_3176_10S_000001.021.jpg and A06_P16_C051_C_211127_3176_10S_000001.021.txt to labeled folder
# Progress: 12169/71293 (17.07%)Copied A06_P16_C051_C_211127_3176_10S_000002.000.jpg and A06_P16_C051_C_211127_3176_10S_000002.000.txt to labeled folder
# Progress: 12170/71293 (17.07%)Copied A06_P16_C051_C_211127_3176_10S_000002.019.jpg and A06_P16_C051_C_211127_3176_10S_000002.019.txt to labeled folder
# Progress: 12171/71293 (17.07%)Copied A06_P16_C051_C_211127_3176_10S_000003.027.jpg and A06_P16_C051_C_211127_3176_10S_000003.027.txt to labeled folder
# Progress: 12172/71293 (17.07%)Copied A06_P16_C051_C_211127_3176_10S_000004.006.jpg and A06_P16_C051_C_211127_3176_10S_000004.006.txt to labeled folder
# Progress: 12173/71293 (17.07%)Copied A06_P16_C051_C_211127_3176_10S_000007.009.jpg and A06_P16_C051_C_211127_3176_10S_000007.009.txt to labeled folder
# Progress: 12174/71293 (17.08%)Copied A06_P16_C051_C_211127_3177_20S_000000.002.jpg and A06_P16_C051_C_211127_3177_20S_000000.002.txt to labeled folder
# Progress: 12175/71293 (17.08%)Copied A06_P16_C051_C_211127_3177_20S_000004.001.jpg and A06_P16_C051_C_211127_3177_20S_000004.001.txt to labeled folder
# Progress: 12176/71293 (17.08%)Copied A06_P16_C051_C_211127_3177_20S_000004.029.jpg and A06_P16_C051_C_211127_3177_20S_000004.029.txt to labeled folder
# Progress: 12177/71293 (17.08%)Copied A06_P16_C051_C_211127_3177_20S_000008.002.jpg and A06_P16_C051_C_211127_3177_20S_000008.002.txt to labeled folder
# Progress: 12178/71293 (17.08%)Copied A06_P16_C051_C_211127_3177_20S_000008.027.jpg and A06_P16_C051_C_211127_3177_20S_000008.027.txt to labeled folder
# Progress: 12179/71293 (17.08%)Copied A06_P16_C051_C_211127_3177_20S_000009.002.jpg and A06_P16_C051_C_211127_3177_20S_000009.002.txt to labeled folder
# Progress: 12180/71293 (17.08%)Copied A06_P16_C051_C_211127_3177_20S_000009.005.jpg and A06_P16_C051_C_211127_3177_20S_000009.005.txt to labeled folder
# Progress: 12181/71293 (17.09%)Copied A06_P16_C051_C_211127_3177_20S_000009.008.jpg and A06_P16_C051_C_211127_3177_20S_000009.008.txt to labeled folder
# Progress: 12182/71293 (17.09%)Copied A06_P16_C051_C_211127_3177_20S_000009.017.jpg and A06_P16_C051_C_211127_3177_20S_000009.017.txt to labeled folder
# Progress: 12183/71293 (17.09%)Copied A06_P16_C051_C_211127_3177_20S_000011.003.jpg and A06_P16_C051_C_211127_3177_20S_000011.003.txt to labeled folder
# Progress: 12184/71293 (17.09%)Copied A06_P16_C051_C_211127_3177_20S_000011.026.jpg and A06_P16_C051_C_211127_3177_20S_000011.026.txt to labeled folder
# Progress: 12185/71293 (17.09%)Copied A06_P16_C051_C_211127_3177_20S_000011.029.jpg and A06_P16_C051_C_211127_3177_20S_000011.029.txt to labeled folder
# Progress: 12186/71293 (17.09%)Copied A06_P16_C051_C_211127_3177_20S_000012.024.jpg and A06_P16_C051_C_211127_3177_20S_000012.024.txt to labeled folder
# Progress: 12187/71293 (17.09%)Copied A06_P16_C051_C_211127_3177_20S_000013.003.jpg and A06_P16_C051_C_211127_3177_20S_000013.003.txt to labeled folder
# Progress: 12188/71293 (17.10%)Copied A06_P16_C051_C_211127_3177_20S_000013.006.jpg and A06_P16_C051_C_211127_3177_20S_000013.006.txt to labeled folder
# Progress: 12189/71293 (17.10%)Copied A06_P16_C051_C_211127_3177_20S_000014.019.jpg and A06_P16_C051_C_211127_3177_20S_000014.019.txt to labeled folder
# Progress: 12190/71293 (17.10%)Copied A06_P16_C051_C_211127_3177_20S_000015.006.jpg and A06_P16_C051_C_211127_3177_20S_000015.006.txt to labeled folder
# Progress: 12191/71293 (17.10%)Copied A06_P16_C051_C_211127_3177_20S_000015.009.jpg and A06_P16_C051_C_211127_3177_20S_000015.009.txt to labeled folder
# Progress: 12192/71293 (17.10%)Copied A06_P16_C051_C_211127_3177_20S_000016.011.jpg and A06_P16_C051_C_211127_3177_20S_000016.011.txt to labeled folder
# Progress: 12193/71293 (17.10%)Copied A06_P16_C051_C_211127_3177_20S_000016.017.jpg and A06_P16_C051_C_211127_3177_20S_000016.017.txt to labeled folder
# Progress: 12194/71293 (17.10%)Copied A06_P16_C051_C_211127_3177_20S_000017.019.jpg and A06_P16_C051_C_211127_3177_20S_000017.019.txt to labeled folder
# Progress: 12195/71293 (17.11%)Copied A06_P16_C051_C_211127_3177_20S_000018.027.jpg and A06_P16_C051_C_211127_3177_20S_000018.027.txt to labeled folder
# Progress: 12196/71293 (17.11%)Copied A06_P16_C051_C_211127_3177_20S_000019.017.jpg and A06_P16_C051_C_211127_3177_20S_000019.017.txt to labeled folder
# Progress: 12197/71293 (17.11%)Copied A06_P16_C051_C_211127_3177_20S_000019.026.jpg and A06_P16_C051_C_211127_3177_20S_000019.026.txt to labeled folder
# Progress: 12198/71293 (17.11%)Copied A06_P16_C051_C_211127_3177_20S_000020.000.jpg and A06_P16_C051_C_211127_3177_20S_000020.000.txt to labeled folder
# Progress: 12199/71293 (17.11%)Copied A06_P16_C051_C_211127_3178_10S_000001.006.jpg and A06_P16_C051_C_211127_3178_10S_000001.006.txt to labeled folder
# Progress: 12200/71293 (17.11%)Copied A06_P16_C051_C_211127_3178_10S_000001.023.jpg and A06_P16_C051_C_211127_3178_10S_000001.023.txt to labeled folder
# Progress: 12201/71293 (17.11%)Copied A06_P16_C051_C_211127_3178_10S_000002.018.jpg and A06_P16_C051_C_211127_3178_10S_000002.018.txt to labeled folder
# Progress: 12202/71293 (17.12%)Copied A06_P16_C051_C_211127_3178_10S_000007.019.jpg and A06_P16_C051_C_211127_3178_10S_000007.019.txt to labeled folder
# Progress: 12203/71293 (17.12%)Copied A06_P16_C051_C_211127_3178_10S_000008.007.jpg and A06_P16_C051_C_211127_3178_10S_000008.007.txt to labeled folder
# Progress: 12204/71293 (17.12%)Copied A06_P16_C051_C_211127_3178_10S_000008.019.jpg and A06_P16_C051_C_211127_3178_10S_000008.019.txt to labeled folder
# Progress: 12205/71293 (17.12%)Copied A06_P16_C051_C_211127_3178_10S_000009.007.jpg and A06_P16_C051_C_211127_3178_10S_000009.007.txt to labeled folder
# Progress: 12206/71293 (17.12%)Copied A06_P16_C051_C_211127_3178_10S_000009.022.jpg and A06_P16_C051_C_211127_3178_10S_000009.022.txt to labeled folder
# Progress: 12207/71293 (17.12%)Copied A06_P16_C051_C_211127_3178_10S_000009.023.jpg and A06_P16_C051_C_211127_3178_10S_000009.023.txt to labeled folder
# Progress: 12208/71293 (17.12%)Copied A06_P16_C051_C_211127_3178_10S_000010.000.jpg and A06_P16_C051_C_211127_3178_10S_000010.000.txt to labeled folder
# Progress: 12209/71293 (17.13%)Copied A06_P16_C051_C_211127_3179_20S_000001.019.jpg and A06_P16_C051_C_211127_3179_20S_000001.019.txt to labeled folder
# Progress: 12210/71293 (17.13%)Copied A06_P16_C051_C_211127_3179_20S_000005.018.jpg and A06_P16_C051_C_211127_3179_20S_000005.018.txt to labeled folder
# Progress: 12211/71293 (17.13%)Copied A06_P16_C051_C_211127_3179_20S_000007.009.jpg and A06_P16_C051_C_211127_3179_20S_000007.009.txt to labeled folder
# Progress: 12212/71293 (17.13%)Copied A06_P16_C051_C_211127_3179_20S_000007.018.jpg and A06_P16_C051_C_211127_3179_20S_000007.018.txt to labeled folder
# Progress: 12213/71293 (17.13%)Copied A06_P16_C051_C_211127_3179_20S_000007.021.jpg and A06_P16_C051_C_211127_3179_20S_000007.021.txt to labeled folder
# Progress: 12214/71293 (17.13%)Copied A06_P16_C051_C_211127_3179_20S_000008.019.jpg and A06_P16_C051_C_211127_3179_20S_000008.019.txt to labeled folder
# Progress: 12215/71293 (17.13%)Copied A06_P16_C051_C_211127_3179_20S_000009.002.jpg and A06_P16_C051_C_211127_3179_20S_000009.002.txt to labeled folder
# Progress: 12216/71293 (17.13%)Copied A06_P16_C051_C_211127_3179_20S_000013.002.jpg and A06_P16_C051_C_211127_3179_20S_000013.002.txt to labeled folder
# Progress: 12217/71293 (17.14%)Copied A06_P16_C051_C_211127_3179_20S_000014.002.jpg and A06_P16_C051_C_211127_3179_20S_000014.002.txt to labeled folder
# Progress: 12218/71293 (17.14%)Copied A06_P16_C051_C_211127_3179_20S_000017.002.jpg and A06_P16_C051_C_211127_3179_20S_000017.002.txt to labeled folder
# Progress: 12219/71293 (17.14%)Copied A06_P16_C051_C_211127_3179_20S_000017.018.jpg and A06_P16_C051_C_211127_3179_20S_000017.018.txt to labeled folder
# Progress: 12220/71293 (17.14%)Copied A06_P16_C051_C_211127_3179_20S_000017.022.jpg and A06_P16_C051_C_211127_3179_20S_000017.022.txt to labeled folder
# Progress: 12221/71293 (17.14%)Copied A06_P16_C051_C_211127_3179_20S_000018.019.jpg and A06_P16_C051_C_211127_3179_20S_000018.019.txt to labeled folder
# Progress: 12222/71293 (17.14%)Copied A06_P16_C051_C_211127_3180_10S_000000.001.jpg and A06_P16_C051_C_211127_3180_10S_000000.001.txt to labeled folder
# Progress: 12223/71293 (17.14%)Copied A06_P16_C051_C_211127_3180_10S_000001.004.jpg and A06_P16_C051_C_211127_3180_10S_000001.004.txt to labeled folder
# Progress: 12224/71293 (17.15%)Copied A06_P16_C051_C_211127_3180_10S_000001.018.jpg and A06_P16_C051_C_211127_3180_10S_000001.018.txt to labeled folder
# Progress: 12225/71293 (17.15%)Copied A06_P16_C051_C_211127_3180_10S_000001.021.jpg and A06_P16_C051_C_211127_3180_10S_000001.021.txt to labeled folder
# Progress: 12226/71293 (17.15%)Copied A06_P16_C051_C_211127_3180_10S_000002.003.jpg and A06_P16_C051_C_211127_3180_10S_000002.003.txt to labeled folder
# Progress: 12227/71293 (17.15%)Copied A06_P16_C051_C_211127_3181_20S_000002.003.jpg and A06_P16_C051_C_211127_3181_20S_000002.003.txt to labeled folder
# Progress: 12228/71293 (17.15%)Copied A06_P16_C051_C_211127_3181_20S_000002.008.jpg and A06_P16_C051_C_211127_3181_20S_000002.008.txt to labeled folder
# Progress: 12229/71293 (17.15%)Copied A06_P16_C051_C_211127_3181_20S_000002.011.jpg and A06_P16_C051_C_211127_3181_20S_000002.011.txt to labeled folder
# Progress: 12230/71293 (17.15%)Copied A06_P16_C051_C_211127_3181_20S_000002.022.jpg and A06_P16_C051_C_211127_3181_20S_000002.022.txt to labeled folder
# Progress: 12231/71293 (17.16%)Copied A06_P16_C051_C_211127_3181_20S_000003.002.jpg and A06_P16_C051_C_211127_3181_20S_000003.002.txt to labeled folder
# Progress: 12232/71293 (17.16%)Copied A06_P16_C051_C_211127_3181_20S_000003.005.jpg and A06_P16_C051_C_211127_3181_20S_000003.005.txt to labeled folder
# Progress: 12233/71293 (17.16%)Copied A06_P16_C051_C_211127_3181_20S_000004.004.jpg and A06_P16_C051_C_211127_3181_20S_000004.004.txt to labeled folder
# Progress: 12234/71293 (17.16%)Copied A06_P16_C051_C_211127_3181_20S_000005.006.jpg and A06_P16_C051_C_211127_3181_20S_000005.006.txt to labeled folder
# Progress: 12235/71293 (17.16%)Copied A06_P16_C051_C_211127_3181_20S_000005.021.jpg and A06_P16_C051_C_211127_3181_20S_000005.021.txt to labeled folder
# Progress: 12236/71293 (17.16%)Copied A06_P16_C051_C_211127_3181_20S_000005.024.jpg and A06_P16_C051_C_211127_3181_20S_000005.024.txt to labeled folder
# Progress: 12237/71293 (17.16%)Copied A06_P16_C051_C_211127_3181_20S_000005.027.jpg and A06_P16_C051_C_211127_3181_20S_000005.027.txt to labeled folder
# Progress: 12238/71293 (17.17%)Copied A06_P16_C051_C_211127_3181_20S_000006.004.jpg and A06_P16_C051_C_211127_3181_20S_000006.004.txt to labeled folder
# Progress: 12239/71293 (17.17%)Copied A06_P16_C051_C_211127_3181_20S_000006.006.jpg and A06_P16_C051_C_211127_3181_20S_000006.006.txt to labeled folder
# Progress: 12240/71293 (17.17%)Copied A06_P16_C051_C_211127_3181_20S_000006.012.jpg and A06_P16_C051_C_211127_3181_20S_000006.012.txt to labeled folder
# Progress: 12241/71293 (17.17%)Copied A06_P16_C051_C_211127_3181_20S_000006.017.jpg and A06_P16_C051_C_211127_3181_20S_000006.017.txt to labeled folder
# Progress: 12242/71293 (17.17%)Copied A06_P16_C051_C_211127_3181_20S_000006.019.jpg and A06_P16_C051_C_211127_3181_20S_000006.019.txt to labeled folder
# Progress: 12243/71293 (17.17%)Copied A06_P16_C051_C_211127_3181_20S_000006.021.jpg and A06_P16_C051_C_211127_3181_20S_000006.021.txt to labeled folder
# Progress: 12244/71293 (17.17%)Copied A06_P16_C051_C_211127_3181_20S_000006.027.jpg and A06_P16_C051_C_211127_3181_20S_000006.027.txt to labeled folder
# Progress: 12245/71293 (17.18%)Copied A06_P16_C051_C_211127_3181_20S_000007.003.jpg and A06_P16_C051_C_211127_3181_20S_000007.003.txt to labeled folder
# Progress: 12246/71293 (17.18%)Copied A06_P16_C051_C_211127_3181_20S_000009.002.jpg and A06_P16_C051_C_211127_3181_20S_000009.002.txt to labeled folder
# Progress: 12247/71293 (17.18%)Copied A06_P16_C051_C_211127_3181_20S_000009.017.jpg and A06_P16_C051_C_211127_3181_20S_000009.017.txt to labeled folder
# Progress: 12248/71293 (17.18%)Copied A06_P16_C051_C_211127_3181_20S_000011.023.jpg and A06_P16_C051_C_211127_3181_20S_000011.023.txt to labeled folder
# Progress: 12249/71293 (17.18%)Copied A06_P16_C051_C_211127_3181_20S_000012.002.jpg and A06_P16_C051_C_211127_3181_20S_000012.002.txt to labeled folder
# Progress: 12250/71293 (17.18%)Copied A06_P16_C051_C_211127_3181_20S_000012.005.jpg and A06_P16_C051_C_211127_3181_20S_000012.005.txt to labeled folder
# Progress: 12251/71293 (17.18%)Copied A06_P16_C051_C_211127_3181_20S_000012.009.jpg and A06_P16_C051_C_211127_3181_20S_000012.009.txt to labeled folder
# Progress: 12252/71293 (17.19%)Copied A06_P16_C051_C_211127_3181_20S_000012.017.jpg and A06_P16_C051_C_211127_3181_20S_000012.017.txt to labeled folder
# Progress: 12253/71293 (17.19%)Copied A06_P16_C051_C_211127_3181_20S_000012.023.jpg and A06_P16_C051_C_211127_3181_20S_000012.023.txt to labeled folder
# Progress: 12254/71293 (17.19%)Copied A06_P16_C051_C_211127_3181_20S_000013.002.jpg and A06_P16_C051_C_211127_3181_20S_000013.002.txt to labeled folder
# Progress: 12255/71293 (17.19%)Copied A06_P16_C051_C_211127_3181_20S_000013.019.jpg and A06_P16_C051_C_211127_3181_20S_000013.019.txt to labeled folder
# Progress: 12256/71293 (17.19%)Copied A06_P16_C051_C_211127_3181_20S_000014.008.jpg and A06_P16_C051_C_211127_3181_20S_000014.008.txt to labeled folder
# Progress: 12257/71293 (17.19%)Copied A06_P16_C051_C_211127_3181_20S_000014.011.jpg and A06_P16_C051_C_211127_3181_20S_000014.011.txt to labeled folder
# Progress: 12258/71293 (17.19%)Copied A06_P16_C051_C_211127_3181_20S_000014.018.jpg and A06_P16_C051_C_211127_3181_20S_000014.018.txt to labeled folder
# Progress: 12259/71293 (17.20%)Copied A06_P16_C051_C_211127_3181_20S_000014.022.jpg and A06_P16_C051_C_211127_3181_20S_000014.022.txt to labeled folder
# Progress: 12260/71293 (17.20%)Copied A06_P16_C051_C_211127_3181_20S_000014.023.jpg and A06_P16_C051_C_211127_3181_20S_000014.023.txt to labeled folder
# Progress: 12261/71293 (17.20%)Copied A06_P16_C051_C_211127_3181_20S_000014.026.jpg and A06_P16_C051_C_211127_3181_20S_000014.026.txt to labeled folder
# Progress: 12262/71293 (17.20%)Copied A06_P16_C051_C_211127_3181_20S_000015.001.jpg and A06_P16_C051_C_211127_3181_20S_000015.001.txt to labeled folder
# Progress: 12263/71293 (17.20%)Copied A06_P16_C051_C_211127_3181_20S_000015.003.jpg and A06_P16_C051_C_211127_3181_20S_000015.003.txt to labeled folder
# Progress: 12264/71293 (17.20%)Copied A06_P16_C051_C_211127_3181_20S_000015.016.jpg and A06_P16_C051_C_211127_3181_20S_000015.016.txt to labeled folder
# Progress: 12265/71293 (17.20%)Copied A06_P16_C051_C_211127_3181_20S_000015.018.jpg and A06_P16_C051_C_211127_3181_20S_000015.018.txt to labeled folder
# Progress: 12266/71293 (17.21%)Copied A06_P16_C051_C_211127_3181_20S_000015.022.jpg and A06_P16_C051_C_211127_3181_20S_000015.022.txt to labeled folder
# Progress: 12267/71293 (17.21%)Copied A06_P16_C051_C_211127_3181_20S_000017.001.jpg and A06_P16_C051_C_211127_3181_20S_000017.001.txt to labeled folder
# Progress: 12268/71293 (17.21%)

# %%
import os
import shutil

def is_valid_yolo_format(file_path):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            for line in lines:
                parts = line.strip().split()
                if len(parts) == 5 and all(part.replace('.', '', 1).isdigit() for part in parts[1:]):
                    return True
    except:
        pass
    return False

def count_total_images(base_path):
    total_images = 0
    for root, _, files in os.walk(base_path):
        if root == base_path:
            continue
        total_images += len([f for f in files if f.lower().endswith('.jpg')])
    return total_images

def process_folders(base_path):
    labeled_folder = os.path.join(base_path, 'labeled')
    
    # 'labeled' 폴더 생성 또는 비우기
    if os.path.exists(labeled_folder):
        shutil.rmtree(labeled_folder)
    os.makedirs(labeled_folder)

    total_images = count_total_images(base_path)
    processed_images = 0

    for root, dirs, files in os.walk(base_path):
        if root == base_path or root == labeled_folder:
            continue

        folder_name = os.path.basename(root)  # 현재 폴더 이름 가져오기
        jpg_files = [f for f in files if f.lower().endswith('.jpg')]
        txt_files = [f for f in files if f.lower().endswith('.txt')]

        for jpg_file in jpg_files:
            processed_images += 1
            txt_file = jpg_file[:-4] + '.txt'
            if txt_file in txt_files:
                txt_path = os.path.join(root, txt_file)
                if is_valid_yolo_format(txt_path):
                    jpg_path = os.path.join(root, jpg_file)
                    
                    # 새 파일 이름 지정 (폴더 이름 + 원본 파일 이름)
                    new_jpg_name = f"{folder_name}_{jpg_file.lower()}"
                    new_txt_name = f"{folder_name}_{txt_file.lower()}"
                    
                    # 복사 경로 설정
                    new_jpg_path = os.path.join(labeled_folder, new_jpg_name)
                    new_txt_path = os.path.join(labeled_folder, new_txt_name)
                    
                    # jpg 파일 복사
                    shutil.copy2(jpg_path, new_jpg_path)
                    # txt 파일 복사
                    shutil.copy2(txt_path, new_txt_path)
                    print(f"Copied {new_jpg_name} and {new_txt_name} to labeled folder")
            
            # 진행률 표시
            progress = (processed_images / total_images) * 100
            print(f"\rProgress: {processed_images}/{total_images} ({progress:.2f}%)", end="", flush=True)

    print("\nProcessing complete.")
    print(f"Total images processed: {processed_images}")
    print(f"Images with valid YOLO labels copied: {len(os.listdir(labeled_folder))//2}")

# 실행
base_path = '/data2/bear/'
process_folders(base_path)

# %% [markdown]
# # 일정 객체 크기 미만 필터

# %%
import os
import shutil

def is_valid_yolo_format(file_path, min_area=0.002):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            valid_objects = []
            for line in lines:
                parts = line.strip().split()
                if len(parts) == 5 and all(part.replace('.', '', 1).isdigit() for part in parts[1:]):
                    _, x, y, width, height = map(float, parts)
                    area = width * height
                    if area >= min_area:
                        valid_objects.append(line.strip())
            
            if valid_objects:
                return True, valid_objects
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        pass
    return False, []

def count_total_images(base_path):
    total_images = 0
    for root, _, files in os.walk(base_path):
        if root == base_path:
            continue
        total_images += len([f for f in files if f.lower().endswith('.jpg')])
    return total_images

def process_folders(base_path):
    labeled_folder = os.path.join(base_path, 'labeled')
    
    # 'labeled' 폴더 생성 또는 비우기
    if os.path.exists(labeled_folder):
        shutil.rmtree(labeled_folder)
    os.makedirs(labeled_folder)

    total_images = count_total_images(base_path)
    processed_images = 0

    for root, dirs, files in os.walk(base_path):
        if root == base_path or root == labeled_folder:
            continue

        folder_name = os.path.basename(root)  # 현재 폴더 이름 가져오기
        jpg_files = [f for f in files if f.lower().endswith('.jpg')]
        txt_files = [f for f in files if f.lower().endswith('.txt')]

        for jpg_file in jpg_files:
            processed_images += 1
            txt_file = jpg_file[:-4] + '.txt'
            if txt_file in txt_files:
                txt_path = os.path.join(root, txt_file)
                is_valid, valid_lines = is_valid_yolo_format(txt_path)
                if is_valid:
                    jpg_path = os.path.join(root, jpg_file)
                    
                    # 새 파일 이름 지정 (폴더 이름 + 원본 파일 이름)
                    new_jpg_name = f"{folder_name}_{jpg_file.lower()}"
                    new_txt_name = f"{folder_name}_{txt_file.lower()}"
                    
                    # 복사 경로 설정
                    new_jpg_path = os.path.join(labeled_folder, new_jpg_name)
                    new_txt_path = os.path.join(labeled_folder, new_txt_name)
                    
                    # jpg 파일 복사
                    shutil.copy2(jpg_path, new_jpg_path)
                    
                    # txt 파일 복사 및 유효한 라인만 저장
                    with open(new_txt_path, 'w') as new_txt_file:
                        new_txt_file.write("\n".join(valid_lines) + "\n")
                    
                    # print(f"Copied {new_jpg_name} and filtered {new_txt_name} to labeled folder")
            
            # 진행률 표시
            # progress = (processed_images / total_images) * 100
            # print(f"\rProgress: {processed_images}/{total_images} ({progress:.2f}%)", end="", flush=True)

    print("\nProcessing complete.")
    print(f"Total images processed: {processed_images}")
    print(f"Images with valid YOLO labels copied: {len(os.listdir(labeled_folder))//2}")

# 실행
base_path = '/data2/bear/'
process_folders(base_path)
# Out:
# Processing complete.
# Total images processed: 71293
# Images with valid YOLO labels copied: 40544

# %% [markdown]
# # width/height ratio , size filter

# %%
import os
import shutil

def is_valid_yolo_format(file_path, min_area=0.003, max_aspect_ratio=3.0):
    try:
        with open(file_path, 'r') as file:
            lines = file.readlines()
            valid_objects = []
            for line in lines:
                parts = line.strip().split()
                if len(parts) == 5 and all(part.replace('.', '', 1).isdigit() for part in parts[1:]):
                    _, x, y, width, height = map(float, parts)
                    area = width * height
                    aspect_ratio = width / height
                    
                    # 면적과 가로 세로 비율을 기준으로 필터링
                    if area >= min_area and aspect_ratio <= max_aspect_ratio:
                        valid_objects.append(line.strip())
            
            if valid_objects:
                return True, valid_objects
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        pass
    return False, []

def count_total_images(base_path):
    total_images = 0
    for root, _, files in os.walk(base_path):
        if root == base_path:
            continue
        total_images += len([f for f in files if f.lower().endswith('.jpg')])
    return total_images

def process_folders(base_path):
    labeled_folder = os.path.join(base_path, labeled)
    
    # 'labeled' 폴더 생성 또는 비우기
    if os.path.exists(labeled_folder):
        shutil.rmtree(labeled_folder)
    os.makedirs(labeled_folder)

    total_images = count_total_images(base_path)
    processed_images = 0

    for root, dirs, files in os.walk(base_path):
        if root == base_path or root == labeled_folder:
            continue

        folder_name = os.path.basename(root)  # 현재 폴더 이름 가져오기
        jpg_files = [f for f in files if f.lower().endswith('.jpg')]
        txt_files = [f for f in files if f.lower().endswith('.txt')]

        for jpg_file in jpg_files:
            processed_images += 1
            txt_file = jpg_file[:-4] + '.txt'
            if txt_file in txt_files:
                txt_path = os.path.join(root, txt_file)
                is_valid, valid_lines = is_valid_yolo_format(txt_path)
                if is_valid:
                    jpg_path = os.path.join(root, jpg_file)
                    
                    # 새 파일 이름 지정 (폴더 이름 + 원본 파일 이름)
                    new_jpg_name = f"{folder_name}_{jpg_file.lower()}"
                    new_txt_name = f"{folder_name}_{txt_file.lower()}"
                    
                    # 복사 경로 설정
                    new_jpg_path = os.path.join(labeled_folder, new_jpg_name)
                    new_txt_path = os.path.join(labeled_folder, new_txt_name)
                    
                    # jpg 파일 복사
                    shutil.copy2(jpg_path, new_jpg_path)
                    
                    # txt 파일 복사 및 유효한 라인만 저장
                    with open(new_txt_path, 'w') as new_txt_file:
                        new_txt_file.write("\n".join(valid_lines) + "\n")
                    
                    # print(f"Copied {new_jpg_name} and filtered {new_txt_name} to labeled folder")
            
            # # 진행률 표시
            # progress = (processed_images / total_images) * 100
            # print(f"\rProgress: {processed_images}/{total_images} ({progress:.2f}%)", end="", flush=True)

    print("\nProcessing complete.")
    print(f"Total images processed: {processed_images}")
    print(f"Images with valid YOLO labels copied: {len(os.listdir(labeled_folder))//2}")

# 실행
base_path = '/data2/bear/'
labeled = 'labeled'
process_folders(base_path)

# 검색할 폴더 경로 설정
folder_path = base_path + labeled
# 결과를 저장할 파일 경로 설정
output_file = "labeled.txt"

# 결과를 저장할 파일 열기
with open(output_file, 'w') as f:
    # 폴더 내의 모든 파일 및 하위 폴더를 탐색
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            # .jpg 확장자 파일만 선택
            if file.endswith(".jpg"):
                # 전체 파일 경로 작성
                file_path = os.path.join(root, file)
                # 경로를 labeled.txt 파일에 기록
                f.write(file_path + "\n")

print(f"모든 .jpg 파일 경로가 {output_file}에 저장되었습니다.")
# Out:
# Processing complete.
# Total images processed: 72270
# Images with valid YOLO labels copied: 47584

# %% [markdown]
# # no filter

# %%
import os
import shutil

def count_total_images(base_path):
    total_images = 0
    for root, _, files in os.walk(base_path):
        if root == base_path:
            continue
        total_images += len([f for f in files if f.lower().endswith('.jpg')])
    return total_images

def process_folders(base_path):
    labeled_folder = os.path.join(base_path, 'labeled')
    
    # 'labeled' 폴더 생성 또는 비우기
    if os.path.exists(labeled_folder):
        shutil.rmtree(labeled_folder)
    os.makedirs(labeled_folder)

    total_images = count_total_images(base_path)
    processed_images = 0

    for root, dirs, files in os.walk(base_path):
        if root == base_path or root == labeled_folder:
            continue

        folder_name = os.path.basename(root)  # 현재 폴더 이름 가져오기
        jpg_files = [f for f in files if f.lower().endswith('.jpg')]
        txt_files = [f for f in files if f.lower().endswith('.txt')]

        for jpg_file in jpg_files:
            processed_images += 1
            txt_file = jpg_file[:-4] + '.txt'
            if txt_file in txt_files:
                jpg_path = os.path.join(root, jpg_file)
                txt_path = os.path.join(root, txt_file)
                
                # 새 파일 이름 지정 (폴더 이름 + 원본 파일 이름)
                new_jpg_name = f"{folder_name}_{jpg_file.lower()}"
                new_txt_name = f"{folder_name}_{txt_file.lower()}"
                
                # 복사 경로 설정
                new_jpg_path = os.path.join(labeled_folder, new_jpg_name)
                new_txt_path = os.path.join(labeled_folder, new_txt_name)
                
                # jpg 파일 복사
                shutil.copy2(jpg_path, new_jpg_path)
                # txt 파일 복사
                shutil.copy2(txt_path, new_txt_path)
                # print(f"Copied {new_jpg_name} and {new_txt_name} to labeled folder")
            
            # # 진행률 표시
            # progress = (processed_images / total_images) * 100
            # print(f"\rProgress: {processed_images}/{total_images} ({progress:.2f}%)", end="", flush=True)

    print("\nProcessing complete.")
    print(f"Total images processed: {processed_images}")
    print(f"Images copied: {len(os.listdir(labeled_folder))//2}")

# 실행
base_path = '/data2/bear/'
process_folders(base_path)
# Out:
# Processing complete.
# Total images processed: 119531
# Images copied: 94008

# %% [markdown]
# ##### find folder/ -type f -name "*.jpg" > labeled.txt

# %% [markdown]
# # split

# %%
#for shuffle
import random
import math

# path = '/home/data2/fire/2023-10-31/fire.txt'
# out_path = '/home/data2/fire/2023-10-31/fire_split.txt'

path = '/home/data2/bear/labeled.txt'
out_path = '/home/data2/bear/bear_split.txt'

train_path = '/home/fishduke/Desktop/darknet/data/bear_csp_train.txt'
valid_path = '/home/fishduke/Desktop/darknet/data/bear_csp_valid.txt'

txt = open(path,'r')
f = open(out_path,'w')

tmp = []

while True :
    line = txt.readline()
    if not line:
        break
        
    tmp.append(line)
    
random.shuffle(tmp)
        
for i in tmp :  
    f.write(i)

txt.close()
f.close()

lines = []

path = out_path

# 파일을 먼저 읽어 전체 라인 수 계산
with open(path, 'r') as txt:
    lines = txt.readlines()

total_lines = len(lines)
split_index = math.ceil(total_lines * 0.1)  # 전체의 10%를 valid로 사용 (반올림 적용)

f = open(train_path, 'w')
f2 = open(valid_path, 'w')

for i, line in enumerate(lines):
    if i < split_index:
        f2.write(line)  # valid 데이터
    else:
        f.write(line)  # train 데이터

f.close()
f2.close()
